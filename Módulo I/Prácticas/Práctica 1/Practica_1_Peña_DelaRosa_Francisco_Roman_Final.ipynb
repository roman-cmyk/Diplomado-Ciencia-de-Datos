# %%
# Import required libraries
import pandas as pd
import numpy as np
import datetime
import re
import unicodedata
import warnings
pd.options.display.max_columns = None
pd.set_option('max_rows', 5000)
pd.options.display.float_format = '{:,.2f}'.format 
warnings.filterwarnings('ignore')

# %% [markdown]
# # **Upload Spotify Dataset**

# %%
# Read spotify dataset
spotify = pd.read_csv('spotify_practica.csv')
print(spotify.shape)
spotify.head(5)
# Out:
# (170349, 20)
#    acousticness               artists  danceability  duration_ms  energy  \
# 0          0.76  ['Shel Silverstein']          0.67       210387    0.17
# 1          0.92      ['Mose Allison']          0.69       149547    0.24
# 2          0.93               ['水柳仙']          0.18       207173    0.09
# 3          0.98       ['Dean Martin']          0.47       182653    0.03
# 4          0.89         ['Doris Day']          0.24       171400    0.34
#
#    explicit                      id  instrumentalness  key  liveness  \
# 0       NaN  1r3N7MoEGPHJyCjBlWCsx3              0.00 2.00      0.13
# 1       NaN  2RL8EkOOu0QhAikhUUvIRi              0.00  NaN      0.08
# 2      0.00  3kKKEghp2EMh8992pWFylr              0.70 7.00      0.11
# 3       NaN  0j3ideT0tRuIyRhOOUQjYa              0.00 7.00      0.15
# 4       NaN  0od9zbD6Bcc8b7dCMRFWBZ              0.00 2.00      0.13
#
#    loudness  mode                 name  popularity         release_date  \
# 0    -13.07     1          The Unicorn       12.00  1962-10-13 00:00:00
# 1    -14.61     0          If You Live       19.00  1963-04-14 00:00:00
# 2    -26.60     1                  鴛鴦夢       23.00  1963-11-14 00:00:00
# 3    -18.01     1        Fools Rush In       21.00  1964-06-07 00:00:00
# 4     -9.81     0  The Christmas Waltz       22.00  1964-08-07 00:00:00
#
#    speechiness  tempo  valence zip Code genero
# 0         0.33  97.08     0.33  38ee029    NaN
# 1         0.04 120.89     0.71   9p2304    NaN
# 2         0.04 101.48     0.13  2166ee6    NaN
# 3         0.04 135.56     0.19    67t06    NaN
# 4         0.03  89.16     0.24   804p53    NaN

# %%
# Identify type of variables in "spotify DataFrame"
spotify.dtypes
# Out:
# acousticness        float64
# artists              object
# danceability        float64
# duration_ms           int64
# energy              float64
# explicit            float64
# id                   object
# instrumentalness    float64
# key                 float64
# liveness            float64
# loudness            float64
# mode                  int64
# name                 object
# popularity          float64
# release_date         object
# speechiness         float64
# tempo               float64
# valence             float64
# zip Code             object
# genero               object
# dtype: object

# %% [markdown]
# ## **(a)** **Tagging Variables By Type**

# %%
# Prefixes for variable types
# 'c_' --> Numeric Variables: Discrete & Continous
# 'v_' --> Categorical Variables
# 'd_' --> Date Type Variables
# 't_' --> Text Type Variables

c_feats = ['acousticness','danceability','duration_ms','energy',
           'instrumentalness','liveness','loudness',
           'speechiness','tempo','valence']
v_feats = ['mode','key','explicit','popularity','genero']
t_feats = ['artists','id','name','zip Code']
d_feats = ['release_date']

#cambiar genero a categorica

# %%
c_feats_new = ['c_' + x for x in c_feats]
v_feats_new = ['v_' + x for x in v_feats]
d_feats_new = ['d_' + x for x in d_feats]
t_feats_new = ['t_' + x for x in t_feats]

# %%
print(list(c_feats))
print(list(c_feats_new))
# Out:
# ['acousticness', 'danceability', 'duration_ms', 'energy', 'instrumentalness', 'liveness', 'loudness', 'speechiness', 'tempo', 'valence']
# ['c_acousticness', 'c_danceability', 'c_duration_ms', 'c_energy', 'c_instrumentalness', 'c_liveness', 'c_loudness', 'c_speechiness', 'c_tempo', 'c_valence']

# %%
# Rename columns according to the type of variable
spotify.rename(columns=dict(zip(d_feats,d_feats_new)),inplace=True)
spotify.rename(columns=dict(zip(v_feats,v_feats_new)),inplace=True)
spotify.rename(columns=dict(zip(t_feats,t_feats_new)),inplace=True)
spotify.rename(columns=dict(zip(c_feats,c_feats_new)),inplace=True)
print(spotify.shape)
spotify.head(3)
# Out:
# (170349, 20)
#    c_acousticness             t_artists  c_danceability  c_duration_ms  \
# 0            0.76  ['Shel Silverstein']            0.67         210387
# 1            0.92      ['Mose Allison']            0.69         149547
# 2            0.93               ['水柳仙']            0.18         207173
#
#    c_energy  v_explicit                    t_id  c_instrumentalness  v_key  \
# 0      0.17         NaN  1r3N7MoEGPHJyCjBlWCsx3                0.00   2.00
# 1      0.24         NaN  2RL8EkOOu0QhAikhUUvIRi                0.00    NaN
# 2      0.09        0.00  3kKKEghp2EMh8992pWFylr                0.70   7.00
#
#    c_liveness  c_loudness  v_mode       t_name  v_popularity  \
# 0        0.13      -13.07       1  The Unicorn         12.00
# 1        0.08      -14.61       0  If You Live         19.00
# 2        0.11      -26.60       1          鴛鴦夢         23.00
#
#         d_release_date  c_speechiness  c_tempo  c_valence t_zip Code v_genero
# 0  1962-10-13 00:00:00           0.33    97.08       0.33    38ee029      NaN
# 1  1963-04-14 00:00:00           0.04   120.89       0.71     9p2304      NaN
# 2  1963-11-14 00:00:00           0.04   101.48       0.13    2166ee6      NaN

# %% [markdown]
# # **Delete Duplicates**

# %% [markdown]
# ## **(b)** **Approach: Delete Duplicates Using: "duplicated()"**

# %%
spotify.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 170344    False
# 170345    False
# 170346    False
# 170347    False
# 170348    False
# Length: 170349, dtype: bool

# %%
spotify[spotify.duplicated()]
# Out:
#         c_acousticness                                          t_artists  \
# 1668              1.00        ['Alexander Scriabin', 'Vladimir Horowitz']
# 1669              0.73                            ['Seweryn Goszczyński']
# 1670              0.78                                    ['The Merlons']
# 1681              1.00        ['Alexander Scriabin', 'Vladimir Horowitz']
# 1683              0.73                            ['Seweryn Goszczyński']
# 1686              0.78                                    ['The Merlons']
# 167836            0.99                                ['Carl Woitschach']
# 167837            0.99           ['Robert Schumann', 'Vladimir Horowitz']
# 167838            0.60                            ['Seweryn Goszczyński']
# 167839            0.99                               ['Francisco Canaro']
# 167840            0.99           ['Frédéric Chopin', 'Vladimir Horowitz']
# 167841            0.99         ['Felix Mendelssohn', 'Vladimir Horowitz']
# 167842            0.96               ['Franz Liszt', 'Vladimir Horowitz']
# 167844            0.99                     ['Francisco Canaro', 'Charlo']
# 167845            0.85                            ['Seweryn Goszczyński']
# 167846            0.99       ['Sergei Rachmaninoff', 'Vladimir Horowitz']
# 167847            0.99           ['Frédéric Chopin', 'Vladimir Horowitz']
# 167849            0.99           ['Robert Schumann', 'Vladimir Horowitz']
# 167850            0.98  ['Ludwig van Beethoven', 'Staatskapelle Berlin...
# 167851            0.99             ['George Butterworth', 'John Cameron']
# 167853            0.99                ['Thomas Arne', 'John Heddle Nash']
# 167854            0.99                               ['Francisco Canaro']
# 167855            0.99         ['Moritz Moszkowski', 'Vladimir Horowitz']
# 167857            0.97           ['Frédéric Chopin', 'Vladimir Horowitz']
# 167858            0.99                               ['Francisco Canaro']
# 167859            0.99                     ['Francisco Canaro', 'Charlo']
# 167860            0.99              ['Roger Quilter', 'John Heddle Nash']
# 167861            0.99                                    ['Hafız Yaşar']
# 167862            0.99           ['Frédéric Chopin', 'Vladimir Horowitz']
# 167863            0.99            ['Muzio Clementi', 'Vladimir Horowitz']
# 167864            0.69                            ['Seweryn Goszczyński']
# 167865            0.99                     ['Francisco Canaro', 'Charlo']
# 167866            0.99                                ['Ignacio Corsini']
# 167867            0.42                              ['Shungi Music Crew']
# 167868            0.99             ['George Butterworth', 'John Cameron']
# 167869            0.98                                ['Ignacio Corsini']
# 167870            0.99                                      ['Perchicot']
# 167873            0.71                            ['Seweryn Goszczyński']
# 167874            0.78                            ['Seweryn Goszczyński']
# 167875            0.98           ['Frédéric Chopin', 'Vladimir Horowitz']
# 167876            0.99         ['Dmitry Kabalevsky', 'Vladimir Horowitz']
# 167878            0.99                               ['Francisco Canaro']
# 167879            0.83                            ['Seweryn Goszczyński']
# 167880            0.66                            ['Seweryn Goszczyński']
# 167881            0.98                               ['Francisco Canaro']
# 167882            0.98           ['Frédéric Chopin', 'Vladimir Horowitz']
# 167883            0.46                              ['Shungi Music Crew']
# 167885            0.99           ['Robert Schumann', 'Vladimir Horowitz']
# 167886            0.99           ['Robert Schumann', 'Vladimir Horowitz']
# 167889            0.99           ['Frédéric Chopin', 'Vladimir Horowitz']
# 167890            0.99                                  ['Paul Whiteman']
# 167892            0.99            ['Muzio Clementi', 'Vladimir Horowitz']
# 167894            0.99                      ['Ted Weems & His Orchestra']
# 167895            0.99                     ['Francisco Canaro', 'Charlo']
# 167896            0.99                                ['Ignacio Corsini']
# 167898            0.99                               ['Francisco Canaro']
# 167899            0.99           ['Robert Schumann', 'Vladimir Horowitz']
# 167900            0.99            ['Muzio Clementi', 'Vladimir Horowitz']
# 167901            0.95                                     ['John Raitt']
# 167902            0.99                               ['Francisco Canaro']
# 167903            0.98                      ['Ted Weems & His Orchestra']
# 167904            0.97           ['Frédéric Chopin', 'Vladimir Horowitz']
# 167906            0.99                                  ['Paul Whiteman']
# 167907            1.00                                ['Ignacio Corsini']
# 167908            0.99             ['Samuel Barber', 'Vladimir Horowitz']
# 167909            0.99           ['Frédéric Chopin', 'Vladimir Horowitz']
# 167910            0.72                            ['Seweryn Goszczyński']
# 167911            0.99           ['Frédéric Chopin', 'Vladimir Horowitz']
# 167913            0.99           ['Frédéric Chopin', 'Vladimir Horowitz']
# 167914            0.99           ['Robert Schumann', 'Vladimir Horowitz']
# 167915            0.99                                  ['Paul Whiteman']
# 167916            0.92                                     ['Leroy Carr']
# 167917            0.99           ['Frédéric Chopin', 'Vladimir Horowitz']
# 167918            0.99           ['Frédéric Chopin', 'Vladimir Horowitz']
# 167920            0.99         ['Dmitry Kabalevsky', 'Vladimir Horowitz']
# 167922            0.99                               ['Francisco Canaro']
# 167923            0.99                                ['Ignacio Corsini']
# 167924            0.99           ['Robert Schumann', 'Vladimir Horowitz']
# 167925            0.99           ['Frédéric Chopin', 'Vladimir Horowitz']
# 167926            0.99                     ['Francisco Canaro', 'Charlo']
# 167927            0.99                              ['Hikmet Rıza Hanım']
# 167928            0.99                               ['Francisco Canaro']
# 167929            0.99                                ['Ignacio Corsini']
# 167931            1.00        ['Alexander Scriabin', 'Vladimir Horowitz']
# 167932            1.00        ['Alexander Scriabin', 'Vladimir Horowitz']
# 167934            0.98                                  ['Elsie Houston']
# 167935            0.99                                ['Ignacio Corsini']
# 167936            0.99                               ['Francisco Canaro']
# 167937            0.98                               ['Αντώνης Νταλγκάς']
# 167938            0.98                          ['Stellakis Perpiniadis']
# 167939            0.99                            ['Αντώνης Διαμαντίδης']
# 167940            0.99  ['S. Loukopoulos', 'Klarino G. Anestopoulos', ...
# 167942            0.95                                 ['Moune De Rivel']
# 167943            0.99                               ['Dimitris Gkogkos']
# 167944            0.96                            ['Giorgos Papasideris']
# 167945            0.99      ['Petros Epitropakis', 'Antonis Kalampousis']
# 167946            0.29                               ['Cellular Project']
# 167948            0.99                     ['Francisco Canaro', 'Charlo']
# 167949            1.00                          ['Sotiris Stasinopoulos']
# 167950            0.97                                    ['Nota Kaleli']
# 167951            0.87                                 ['Robert Francis']
# 167952            0.99              ['Francisco Canaro', 'Roberto Maida']
# 167953            0.99                                   ['The Caresser']
# 167955            0.99      ['Francisco Canaro', 'Charlo', 'Angel Ramos']
# 167956            0.98                                 ['Κώστας Δούσιας']
# 167957            1.00                                ['Miltiadis Kazis']
# 167958            0.98                                  ['Carlos Gardel']
# 167959            0.98                                  ['Raquel Meller']
# 167960            0.99      ["Sam Manning's and His Cole Jazz Orchestra"]
# 167961            0.82                                ['The Four Deuces']
# 167962            0.94  ['Banda del Regimiento Pérez 3 de Infantería',...
# 167963            0.00                                   ['Shiny Gnomes']
# 167964            0.94       ['Petros Epitropakis', 'Elvira Nte Ntalgko']
# 167966            0.99                                    ['Paradosiako']
# 167967            0.99                     ['Francisco Canaro', 'Charlo']
# 167968            0.94                        ['Ioannis Panagiotopoulos']
# 167969            0.98                                 ['Los Peregrinos']
# 167970            0.99                            ['Giorgos Papasideris']
# 167971            0.99                                      ['D.roitman']
# 167972            0.99                                ['Carlos Galhardo']
# 167973            0.99                            ['Smt. Angurbala Devi']
# 167974            0.94                                  ['Roza Eskenazi']
# 167975            1.00                               ['Marika Papaggika']
# 167977            0.99                                ['Pirros Xronidis']
# 167978            0.99                                ['Ignacio Corsini']
# 167980            0.99                              ['Dimitris Arapakis']
# 167981            0.99                            ['Giorgos Papasideris']
# 167982            1.00                            ['Giorgos Papasideris']
# 167984            0.98                        ['Gene Sedric', 'Al Casey']
# 167985            0.96                               ['Francisco Canaro']
# 167986            0.99                                ['Kostas Tsanakos']
# 167987            0.99                     ['Francisco Canaro', 'Charlo']
# 167988            0.91  ['Sy Oliver', 'Attila the Hun', 'Jimmie Luncef...
# 167989            0.99                              ['Patrício Teixeira']
# 167990            0.80                                 ['Robert Francis']
# 167992            0.99                               ['ANTONIS NTALGKAS']
# 167994            0.98               ['Francisco Canaro', 'Ernesto Fama']
# 167995            0.99                     ['Francisco Canaro', 'Charlo']
# 167998            0.99                                 ['Hrisoula Stini']
# 167999            0.97                                 ['Lord Kitchener']
# 168001            0.98                 ['Manuel Ponce', 'Andrés Segovia']
# 168002            0.99                            ['Fragiskos Dimitriou']
# 168003            0.97                               ['Francisco Canaro']
# 168004            0.99               ['Giorgos Mpekas', 'Polixeni LItou']
# 168005            0.99                          ['Dimitris Filipopoulos']
# 168006            0.95                                  ['Carlos Gardel']
# 168007            0.98                                ['Ignacio Corsini']
# 168008            0.97                  ['Francisco Canaro', 'Luis Díaz']
# 168009            0.92                      ['Paradosiako Har. Margelis']
# 168010            0.99                                ['Ignacio Corsini']
# 168011            0.99                                  ['Raquel Meller']
# 168012            0.99                ['Renos Talmas', 'Panos Visvardis']
# 168013            0.98                               ["Scarlet D'Carpio"]
# 168016            0.96                            ['Giorgos Papasideris']
# 168017            0.97                                 ['Lord Kitchener']
# 168018            0.68        ['Oρχήστρα Β.Reibold', 'Τέτος Δημητριάδης']
# 168019            1.00                          ['Sotiris Stasinopoulos']
# 168020            0.99                            ['Αντώνης Διαμαντίδης']
# 168021            0.99                                  ['Kostas Nouros']
# 168022            0.99                                   ['Rita Ampatzi']
# 168023            0.99                                  ['Raquel Meller']
# 168024            0.99        ['Danai Stratigopoulou', 'Panos Visvardis']
# 168025            0.99                               ['Γιώργος Κατσαρός']
# 168026            0.99            ['Giota Lidia', 'Prodromos Tsaousakis']
# 168027            0.99                                 ['Sofia Iatridou']
# 168028            0.99                                  ['Roza Eskenazi']
# 168029            0.98  ['Federico Moreno Torroba', 'Vicente Gomez', '...
# 168031            0.99                     ['Francisco Canaro', 'Charlo']
# 168032            0.99                                      ['D.roitman']
# 168033            0.75                 ['Sinclair Lewis', 'Frank Arnold']
# 168034            0.92         ['Franz Joseph Haydn', 'Pro Arte Quartet']
# 168035            0.56                 ['Sinclair Lewis', 'Frank Arnold']
# 168037            0.49                               ['Эрнест Хемингуэй']
# 168038            0.98                               ['Nikos Karakostas']
# 168039            0.95         ['Franz Joseph Haydn', 'Pro Arte Quartet']
# 168040            0.99                  ['Margarita Cueto', 'Jorge Añez']
# 168041            0.97                                ['Cristian Vasile']
# 168042            0.96                               ['Viorel Demetriad']
# 168043            0.71                 ['Sinclair Lewis', 'Frank Arnold']
# 168044            0.97         ['Franz Joseph Haydn', 'Pro Arte Quartet']
# 168046            0.97                                ['Petre Alexandru']
# 168047            0.92  ['Johannes Brahms', 'Karl Böhm', 'Staatskapell...
# 168048            0.33                               ['Эрнест Хемингуэй']
# 168049            0.99                 ['Samuel Barber', 'Marilyn Horne']
# 168050            0.78  ['Anton Bruckner', 'Karl Böhm', 'Staatskapelle...
# 168051            0.95         ['Franz Joseph Haydn', 'Pro Arte Quartet']
# 168052            0.96                                ['Cristian Vasile']
# 168388            0.99                                ['Carl Woitschach']
# 168389            0.60                            ['Seweryn Goszczyński']
# 168390            0.99           ['Frédéric Chopin', 'Vladimir Horowitz']
# 168391            0.96               ['Franz Liszt', 'Vladimir Horowitz']
# 168392            0.99                     ['Francisco Canaro', 'Charlo']
# 168393            0.85                            ['Seweryn Goszczyński']
# 168394            0.99       ['Sergei Rachmaninoff', 'Vladimir Horowitz']
# 168395            0.99           ['Frédéric Chopin', 'Vladimir Horowitz']
# 168397            0.98  ['Ludwig van Beethoven', 'Staatskapelle Berlin...
# 168398            0.99             ['George Butterworth', 'John Cameron']
# 168400            0.99                ['Thomas Arne', 'John Heddle Nash']
# 168401            0.99                               ['Francisco Canaro']
# 168402            0.99         ['Moritz Moszkowski', 'Vladimir Horowitz']
# 168405            0.99                     ['Francisco Canaro', 'Charlo']
# 168406            0.99              ['Roger Quilter', 'John Heddle Nash']
# 168407            0.99                                    ['Hafız Yaşar']
# 168408            0.99           ['Frédéric Chopin', 'Vladimir Horowitz']
# 168409            0.99            ['Muzio Clementi', 'Vladimir Horowitz']
# 168410            0.69                            ['Seweryn Goszczyński']
# 168411            0.99                     ['Francisco Canaro', 'Charlo']
# 168412            0.99                                ['Ignacio Corsini']
# 168413            0.42                              ['Shungi Music Crew']
# 168415            0.98                                ['Ignacio Corsini']
# 168416            0.99                                      ['Perchicot']
# 168418            0.99                               ['Francisco Canaro']
# 168419            0.71                            ['Seweryn Goszczyński']
# 168420            0.78                            ['Seweryn Goszczyński']
# 168421            0.98           ['Frédéric Chopin', 'Vladimir Horowitz']
# 168424            0.99                               ['Francisco Canaro']
# 168425            0.83                            ['Seweryn Goszczyński']
# 168426            0.66                            ['Seweryn Goszczyński']
# 168427            0.98                               ['Francisco Canaro']
# 168428            0.98           ['Frédéric Chopin', 'Vladimir Horowitz']
# 168429            0.46                              ['Shungi Music Crew']
# 168431            0.99           ['Robert Schumann', 'Vladimir Horowitz']
# 168432            0.99           ['Robert Schumann', 'Vladimir Horowitz']
# 168435            0.99           ['Frédéric Chopin', 'Vladimir Horowitz']
# 168436            0.99                                  ['Paul Whiteman']
# 168437            0.99                     ['Francisco Canaro', 'Charlo']
# 168438            0.99            ['Muzio Clementi', 'Vladimir Horowitz']
# 168440            0.99                      ['Ted Weems & His Orchestra']
# 168441            0.99                     ['Francisco Canaro', 'Charlo']
# 168442            0.99                                ['Ignacio Corsini']
# 168444            0.99                               ['Francisco Canaro']
# 168446            0.99            ['Muzio Clementi', 'Vladimir Horowitz']
# 168447            0.95                                     ['John Raitt']
# 168448            0.99                               ['Francisco Canaro']
# 168449            0.98                      ['Ted Weems & His Orchestra']
# 168450            0.97           ['Frédéric Chopin', 'Vladimir Horowitz']
# 168452            0.99                                  ['Paul Whiteman']
# 168453            1.00                                ['Ignacio Corsini']
# 168454            0.99           ['Frédéric Chopin', 'Vladimir Horowitz']
# 168455            0.72                            ['Seweryn Goszczyński']
# 168456            0.99                     ['Francisco Canaro', 'Charlo']
# 168457            0.99           ['Frédéric Chopin', 'Vladimir Horowitz']
# 168458            0.99           ['Robert Schumann', 'Vladimir Horowitz']
# 168459            0.99                                  ['Paul Whiteman']
# 168460            0.92                                     ['Leroy Carr']
# 168461            0.99           ['Frédéric Chopin', 'Vladimir Horowitz']
# 168462            0.99           ['Frédéric Chopin', 'Vladimir Horowitz']
# 168464            0.99         ['Dmitry Kabalevsky', 'Vladimir Horowitz']
# 168466            0.99                               ['Francisco Canaro']
# 168467            0.99                                ['Ignacio Corsini']
# 168468            0.99           ['Robert Schumann', 'Vladimir Horowitz']
# 168469            0.99           ['Frédéric Chopin', 'Vladimir Horowitz']
# 168470            0.99                     ['Francisco Canaro', 'Charlo']
# 168471            0.99                              ['Hikmet Rıza Hanım']
# 168472            0.99                               ['Francisco Canaro']
# 168473            0.99                                ['Ignacio Corsini']
# 168474            0.99                     ['Francisco Canaro', 'Charlo']
# 168475            1.00        ['Alexander Scriabin', 'Vladimir Horowitz']
# 168476            1.00        ['Alexander Scriabin', 'Vladimir Horowitz']
# 168477            0.10                              ['Shungi Music Crew']
# 168478            0.98                                  ['Elsie Houston']
# 168479            0.99                                ['Ignacio Corsini']
# 168480            0.99                               ['Francisco Canaro']
# 168482            0.98                          ['Stellakis Perpiniadis']
# 168483            0.99                            ['Αντώνης Διαμαντίδης']
# 168484            0.99  ['S. Loukopoulos', 'Klarino G. Anestopoulos', ...
# 168486            0.95                                 ['Moune De Rivel']
# 168487            0.99                               ['Dimitris Gkogkos']
# 168488            0.96                            ['Giorgos Papasideris']
# 168489            0.99      ['Petros Epitropakis', 'Antonis Kalampousis']
# 168490            0.29                               ['Cellular Project']
# 168492            0.99                     ['Francisco Canaro', 'Charlo']
# 168494            0.97                                    ['Nota Kaleli']
# 168495            0.87                                 ['Robert Francis']
# 168496            0.99              ['Francisco Canaro', 'Roberto Maida']
# 168497            0.99                                   ['The Caresser']
# 168498            0.99                               ['Soula Karagiorgi']
# 168499            0.99      ['Francisco Canaro', 'Charlo', 'Angel Ramos']
# 168500            0.98                                 ['Κώστας Δούσιας']
# 168501            1.00                                ['Miltiadis Kazis']
# 168502            0.98                                  ['Carlos Gardel']
# 168503            0.98                                  ['Raquel Meller']
# 168504            0.99      ["Sam Manning's and His Cole Jazz Orchestra"]
# 168505            0.82                                ['The Four Deuces']
# 168506            0.94  ['Banda del Regimiento Pérez 3 de Infantería',...
# 168507            0.00                                   ['Shiny Gnomes']
# 168508            0.94       ['Petros Epitropakis', 'Elvira Nte Ntalgko']
# 168509            0.97                                  ['Carlos Gardel']
# 168510            0.99                                    ['Paradosiako']
# 168511            0.99                     ['Francisco Canaro', 'Charlo']
# 168512            0.94                        ['Ioannis Panagiotopoulos']
# 168513            0.98                                 ['Los Peregrinos']
# 168514            0.99                            ['Giorgos Papasideris']
# 168516            0.99                                ['Carlos Galhardo']
# 168517            0.99                            ['Smt. Angurbala Devi']
# 168518            0.94                                  ['Roza Eskenazi']
# 168519            1.00                               ['Marika Papaggika']
# 168521            0.99                                ['Pirros Xronidis']
# 168522            0.99                                ['Ignacio Corsini']
# 168524            0.99                              ['Dimitris Arapakis']
# 168525            0.99                            ['Giorgos Papasideris']
# 168526            1.00                            ['Giorgos Papasideris']
# 168528            0.98                        ['Gene Sedric', 'Al Casey']
# 168529            0.96                               ['Francisco Canaro']
# 168530            0.99                                ['Kostas Tsanakos']
# 168531            0.99                     ['Francisco Canaro', 'Charlo']
# 168532            0.91  ['Sy Oliver', 'Attila the Hun', 'Jimmie Luncef...
# 168533            0.99                              ['Patrício Teixeira']
# 168534            0.80                                 ['Robert Francis']
# 168536            0.99                               ['ANTONIS NTALGKAS']
# 168537            0.99                               ['Kostas Roukounas']
# 168538            0.98               ['Francisco Canaro', 'Ernesto Fama']
# 168541            0.99                     ['Francisco Canaro', 'Charlo']
# 168542            0.99                                 ['Hrisoula Stini']
# 168543            0.97                                 ['Lord Kitchener']
# 168545            0.98                 ['Manuel Ponce', 'Andrés Segovia']
# 168546            0.99                            ['Fragiskos Dimitriou']
# 168547            0.97                               ['Francisco Canaro']
# 168548            0.99               ['Giorgos Mpekas', 'Polixeni LItou']
# 168550            0.95                                  ['Carlos Gardel']
# 168551            0.98                                ['Ignacio Corsini']
# 168552            0.97                  ['Francisco Canaro', 'Luis Díaz']
# 168553            0.92                      ['Paradosiako Har. Margelis']
# 168554            0.99                                ['Ignacio Corsini']
# 168555            0.99                                  ['Raquel Meller']
# 168556            0.99                ['Renos Talmas', 'Panos Visvardis']
# 168557            0.98                               ["Scarlet D'Carpio"]
# 168558            0.98             ['Dimitris Gkogkos', 'Manolis Xiotis']
# 168559            0.99                          ['Dimitris Filipopoulos']
# 168560            0.96                            ['Giorgos Papasideris']
# 168561            0.97                                 ['Lord Kitchener']
# 168562            0.68        ['Oρχήστρα Β.Reibold', 'Τέτος Δημητριάδης']
# 168563            1.00                          ['Sotiris Stasinopoulos']
# 168564            0.99                            ['Αντώνης Διαμαντίδης']
# 168565            0.99                                  ['Kostas Nouros']
# 168566            0.99                                   ['Rita Ampatzi']
# 168567            0.99                                  ['Raquel Meller']
# 168568            0.99        ['Danai Stratigopoulou', 'Panos Visvardis']
# 168569            0.99                               ['Γιώργος Κατσαρός']
# 168570            0.99            ['Giota Lidia', 'Prodromos Tsaousakis']
# 168571            0.99                                 ['Sofia Iatridou']
# 168572            0.99                                  ['Roza Eskenazi']
# 168573            0.98  ['Federico Moreno Torroba', 'Vicente Gomez', '...
# 168575            0.99                     ['Francisco Canaro', 'Charlo']
# 168576            0.99                                      ['D.roitman']
# 168577            0.75                 ['Sinclair Lewis', 'Frank Arnold']
# 168578            0.92         ['Franz Joseph Haydn', 'Pro Arte Quartet']
# 168579            0.56                 ['Sinclair Lewis', 'Frank Arnold']
# 168580            0.70                 ['Sinclair Lewis', 'Frank Arnold']
# 168581            0.49                               ['Эрнест Хемингуэй']
# 168582            0.98                               ['Nikos Karakostas']
# 168583            0.95         ['Franz Joseph Haydn', 'Pro Arte Quartet']
# 168584            0.99                  ['Margarita Cueto', 'Jorge Añez']
# 168585            0.97                                ['Cristian Vasile']
# 168586            0.96                               ['Viorel Demetriad']
# 168587            0.71                 ['Sinclair Lewis', 'Frank Arnold']
# 168588            0.97         ['Franz Joseph Haydn', 'Pro Arte Quartet']
# 168590            0.97                                ['Petre Alexandru']
# 168591            0.92  ['Johannes Brahms', 'Karl Böhm', 'Staatskapell...
# 168592            0.33                               ['Эрнест Хемингуэй']
# 168593            0.99                 ['Samuel Barber', 'Marilyn Horne']
# 168594            0.78  ['Anton Bruckner', 'Karl Böhm', 'Staatskapelle...
# 168595            0.95         ['Franz Joseph Haydn', 'Pro Arte Quartet']
# 168596            0.96                                ['Cristian Vasile']
#
#         c_danceability  c_duration_ms  c_energy  v_explicit  \
# 1668              0.32         326067      0.15        0.00
# 1669              0.72         100700      0.29        0.00
# 1670              0.43         128707      0.53         NaN
# 1681              0.32         326067      0.15        0.00
# 1683              0.72         100700      0.29        0.00
# 1686              0.43         128707      0.53         NaN
# 167836            0.71         158648      0.20         NaN
# 167837            0.38         282133      0.01         NaN
# 167838            0.75         104300      0.22        0.00
# 167839            0.78         180760      0.13        0.00
# 167840            0.21         687733      0.20        0.00
# 167841            0.42         352600      0.12         NaN
# 167842            0.44         136627      0.20         NaN
# 167844            0.68         162493      0.21        0.00
# 167845            0.67         111600      0.20         NaN
# 167846            0.38         590293      0.07         NaN
# 167847            0.17          85133      0.08        0.00
# 167849            0.31         167333      0.01        0.00
# 167850            0.34         276563      0.10        0.00
# 167851            0.32         184840      0.01        0.00
# 167853            0.57         122533      0.15         NaN
# 167854            0.76         173707      0.13         NaN
# 167855            0.35          80800      0.13        0.00
# 167857            0.28         245440      0.09        0.00
# 167858            0.81         169720      0.17         NaN
# 167859            0.70         166000      0.22        0.00
# 167860            0.54         152600      0.10        0.00
# 167861            0.57         162197      0.33        0.00
# 167862            0.38         505920      0.12         NaN
# 167863            0.28         251960      0.04        0.00
# 167864            0.71         102200      0.22        0.00
# 167865            0.77         177507      0.23         NaN
# 167866            0.53         159107      0.12        0.00
# 167867            0.66         372962      0.61        0.00
# 167868            0.24         173293      0.03         NaN
# 167869            0.67         151840      0.26         NaN
# 167870            0.77         140267      0.44        0.00
# 167873            0.68          95900      0.20        0.00
# 167874            0.74         139100      0.28        0.00
# 167875            0.30         215267      0.08         NaN
# 167876            0.37         285133      0.09         NaN
# 167878            0.73         174720      0.19        0.00
# 167879            0.73         108800      0.25        0.00
# 167880            0.63         109900      0.23         NaN
# 167881            0.81         169160      0.30        0.00
# 167882            0.35         138013      0.05        0.00
# 167883            0.73         369721      0.61         NaN
# 167885            0.32         118093      0.00        0.00
# 167886            0.47         158973      0.02         NaN
# 167889            0.23         519933      0.11        0.00
# 167890            0.64         161587      0.19         NaN
# 167892            0.22         351000      0.01         NaN
# 167894            0.84         162147      0.37        0.00
# 167895            0.83         175493      0.20         NaN
# 167896            0.71         130813      0.15         NaN
# 167898            0.81         194413      0.21        0.00
# 167899            0.37         163800      0.12        0.00
# 167900            0.32         214667      0.09        0.00
# 167901            0.33         122733      0.15         NaN
# 167902            0.61         303493      0.19        0.00
# 167903            0.76         180147      0.49         NaN
# 167904            0.19         236493      0.09         NaN
# 167906            0.44         201053      0.05         NaN
# 167907            0.68         145973      0.13         NaN
# 167908            0.24         115627      0.15        0.00
# 167909            0.44         104013      0.04        0.00
# 167910            0.79         107800      0.23         NaN
# 167911            0.27         473227      0.28         NaN
# 167913            0.28         254107      0.05        0.00
# 167914            0.39          94307      0.26        0.00
# 167915            0.52         202173      0.09        0.00
# 167916            0.75         184840      0.19        0.00
# 167917            0.30         785427      0.08        0.00
# 167918            0.41         318267      0.02        0.00
# 167920            0.27         350373      0.24        0.00
# 167922            0.79         160000      0.17        0.00
# 167923            0.58         136160      0.33        0.00
# 167924            0.32          76960      0.19        0.00
# 167925            0.24         340973      0.06        0.00
# 167926            0.78         161000      0.24         NaN
# 167927            0.45         159496      0.17        0.00
# 167928            0.77         184000      0.20        0.00
# 167929            0.60         135507      0.14        0.00
# 167931            0.28         288907      0.00        0.00
# 167932            0.39          48627      0.05         NaN
# 167934            0.78         117362      0.55         NaN
# 167935            0.55         168653      0.13         NaN
# 167936            0.75         186000      0.16        0.00
# 167937            0.27         200693      0.10        0.00
# 167938            0.50         188120      0.46         NaN
# 167939            0.41         165520      0.23         NaN
# 167940            0.37         204840      0.26        0.00
# 167942            0.69         169509      0.71        0.00
# 167943            0.55         194880      0.28        0.00
# 167944            0.32         185307      0.53         NaN
# 167945            0.14         211399      0.33        0.00
# 167946            0.34         192332      0.86        0.00
# 167948            0.45         185507      0.29        0.00
# 167949            0.27         271560      0.32        0.00
# 167950            0.74          30000      0.51         NaN
# 167951            0.35         137090      0.08         NaN
# 167952            0.52         174493      0.46         NaN
# 167953            0.57         189571      0.37         NaN
# 167955            0.60         202000      0.17        0.00
# 167956            0.61         240160      0.38         NaN
# 167957            0.40         253121      0.35         NaN
# 167958            0.71         165200      0.26         NaN
# 167959            0.73         157246      0.16         NaN
# 167960            0.66         173333      0.28         NaN
# 167961            0.63         132400      0.80        0.00
# 167962            0.63         184086      0.71         NaN
# 167963            0.45         224360      0.87        0.00
# 167964            0.43         187294      0.46        0.00
# 167966            0.31         208704      0.32        0.00
# 167967            0.37         204000      0.24        0.00
# 167968            0.59         192347      0.54        0.00
# 167969            0.45         175882      0.45        0.00
# 167970            0.43         182733      0.21        0.00
# 167971            0.33         257493      0.11         NaN
# 167972            0.71         197092      0.62        0.00
# 167973            0.43         193280      0.15         NaN
# 167974            0.35         203600      0.39         NaN
# 167975            0.48         247360      0.40        0.00
# 167977            0.42         192587      0.41         NaN
# 167978            0.64         177787      0.14        0.00
# 167980            0.37         181693      0.29        0.00
# 167981            0.37         175493      0.26        0.00
# 167982            0.39         175827      0.41        0.00
# 167984            0.56         166893      0.19         NaN
# 167985            0.77         171000      0.25        0.00
# 167986            0.47          30000      0.28         NaN
# 167987            0.63         179493      0.25         NaN
# 167988            0.80         176120      0.17        0.00
# 167989            0.53         196043      0.20         NaN
# 167990            0.51         150777      0.27         NaN
# 167992            0.43         196693      0.31        0.00
# 167994            0.68         197507      0.31         NaN
# 167995            0.70         179507      0.27        0.00
# 167998            0.49         200760      0.26        0.00
# 167999            0.82         179080      0.56         NaN
# 168001            0.39         165960      0.11         NaN
# 168002            0.29         223787      0.21        0.00
# 168003            0.72         177000      0.30        0.00
# 168004            0.55         194880      0.29         NaN
# 168005            0.32         201613      0.55        0.00
# 168006            0.70         160307      0.20         NaN
# 168007            0.55         135987      0.32        0.00
# 168008            0.53         163000      0.33         NaN
# 168009            0.47         182571      0.57         NaN
# 168010            0.74         149640      0.18        0.00
# 168011            0.53         155246      0.23         NaN
# 168012            0.34         197680      0.40        0.00
# 168013            0.40         142443      0.19         NaN
# 168016            0.44         202213      0.45         NaN
# 168017            0.68         182413      0.58         NaN
# 168018            0.57         172347      0.54        0.00
# 168019            0.36         257280      0.28        0.00
# 168020            0.38         190560      0.32         NaN
# 168021            0.47         181493      0.17         NaN
# 168022            0.49         188200      0.25         NaN
# 168023            0.62         164800      0.17        0.00
# 168024            0.39         182173      0.32        0.00
# 168025            0.51         174667      0.28        0.00
# 168026            0.61         204840      0.31        0.00
# 168027            0.40         221587      0.54         NaN
# 168028            0.47         201173      0.45        0.00
# 168029            0.53         159896      0.20         NaN
# 168031            0.44         192000      0.07        0.00
# 168032            0.27         255040      0.15        0.00
# 168033            0.63         320145      0.20         NaN
# 168034            0.50         149000      0.04         NaN
# 168035            0.72         273072      0.25         NaN
# 168037            0.63         109512      0.23        1.00
# 168038            0.59         192613      0.59        0.00
# 168039            0.38         268947      0.09        0.00
# 168040            0.75         210991      0.13         NaN
# 168041            0.34         180088      0.52         NaN
# 168042            0.61         156970      0.36         NaN
# 168043            0.67         326832      0.15        0.00
# 168044            0.55         192667      0.06        0.00
# 168046            0.36         157962      0.43         NaN
# 168047            0.21         754480      0.17        0.00
# 168048            0.71         118585      0.18        1.00
# 168049            0.23         155867      0.16         NaN
# 168050            0.16        1170280      0.12        0.00
# 168051            0.40         276160      0.17         NaN
# 168052            0.60         170606      0.32        0.00
# 168388            0.71         158648      0.20         NaN
# 168389            0.75         104300      0.22        0.00
# 168390            0.21         687733      0.20        0.00
# 168391            0.44         136627      0.20         NaN
# 168392            0.68         162493      0.21        0.00
# 168393            0.67         111600      0.20         NaN
# 168394            0.38         590293      0.07         NaN
# 168395            0.17          85133      0.08        0.00
# 168397            0.34         276563      0.10        0.00
# 168398            0.32         184840      0.01        0.00
# 168400            0.57         122533      0.15         NaN
# 168401            0.76         173707      0.13         NaN
# 168402            0.35          80800      0.13        0.00
# 168405            0.70         166000      0.22        0.00
# 168406            0.54         152600      0.10        0.00
# 168407            0.57         162197      0.33        0.00
# 168408            0.38         505920      0.12         NaN
# 168409            0.28         251960      0.04        0.00
# 168410            0.71         102200      0.22        0.00
# 168411            0.77         177507      0.23         NaN
# 168412            0.53         159107      0.12        0.00
# 168413            0.66         372962      0.61        0.00
# 168415            0.67         151840      0.26         NaN
# 168416            0.77         140267      0.44        0.00
# 168418            0.85         200213      0.15        0.00
# 168419            0.68          95900      0.20        0.00
# 168420            0.74         139100      0.28        0.00
# 168421            0.30         215267      0.08         NaN
# 168424            0.73         174720      0.19        0.00
# 168425            0.73         108800      0.25        0.00
# 168426            0.63         109900      0.23         NaN
# 168427            0.81         169160      0.30        0.00
# 168428            0.35         138013      0.05        0.00
# 168429            0.73         369721      0.61         NaN
# 168431            0.32         118093      0.00        0.00
# 168432            0.47         158973      0.02         NaN
# 168435            0.23         519933      0.11        0.00
# 168436            0.64         161587      0.19         NaN
# 168437            0.46         204867      0.20        0.00
# 168438            0.22         351000      0.01         NaN
# 168440            0.84         162147      0.37        0.00
# 168441            0.83         175493      0.20         NaN
# 168442            0.71         130813      0.15         NaN
# 168444            0.81         194413      0.21        0.00
# 168446            0.32         214667      0.09        0.00
# 168447            0.33         122733      0.15         NaN
# 168448            0.61         303493      0.19        0.00
# 168449            0.76         180147      0.49         NaN
# 168450            0.19         236493      0.09         NaN
# 168452            0.44         201053      0.05         NaN
# 168453            0.68         145973      0.13         NaN
# 168454            0.44         104013      0.04        0.00
# 168455            0.79         107800      0.23         NaN
# 168456            0.47         204000      0.16         NaN
# 168457            0.28         254107      0.05        0.00
# 168458            0.39          94307      0.26        0.00
# 168459            0.52         202173      0.09        0.00
# 168460            0.75         184840      0.19        0.00
# 168461            0.30         785427      0.08        0.00
# 168462            0.41         318267      0.02        0.00
# 168464            0.27         350373      0.24        0.00
# 168466            0.79         160000      0.17        0.00
# 168467            0.58         136160      0.33        0.00
# 168468            0.32          76960      0.19        0.00
# 168469            0.24         340973      0.06        0.00
# 168470            0.78         161000      0.24         NaN
# 168471            0.45         159496      0.17        0.00
# 168472            0.77         184000      0.20        0.00
# 168473            0.60         135507      0.14        0.00
# 168474            0.61         170000      0.20        0.00
# 168475            0.28         288907      0.00        0.00
# 168476            0.39          48627      0.05         NaN
# 168477            0.70         388115      0.84         NaN
# 168478            0.78         117362      0.55         NaN
# 168479            0.55         168653      0.13         NaN
# 168480            0.75         186000      0.16        0.00
# 168482            0.50         188120      0.46         NaN
# 168483            0.41         165520      0.23         NaN
# 168484            0.37         204840      0.26        0.00
# 168486            0.69         169509      0.71        0.00
# 168487            0.55         194880      0.28        0.00
# 168488            0.32         185307      0.53         NaN
# 168489            0.14         211399      0.33        0.00
# 168490            0.34         192332      0.86        0.00
# 168492            0.45         185507      0.29        0.00
# 168494            0.74          30000      0.51         NaN
# 168495            0.35         137090      0.08         NaN
# 168496            0.52         174493      0.46         NaN
# 168497            0.57         189571      0.37         NaN
# 168498            0.36         182733      0.35        0.00
# 168499            0.60         202000      0.17        0.00
# 168500            0.61         240160      0.38         NaN
# 168501            0.40         253121      0.35         NaN
# 168502            0.71         165200      0.26         NaN
# 168503            0.73         157246      0.16         NaN
# 168504            0.66         173333      0.28         NaN
# 168505            0.63         132400      0.80        0.00
# 168506            0.63         184086      0.71         NaN
# 168507            0.45         224360      0.87        0.00
# 168508            0.43         187294      0.46        0.00
# 168509            0.72         140573      0.24        0.00
# 168510            0.31         208704      0.32        0.00
# 168511            0.37         204000      0.24        0.00
# 168512            0.59         192347      0.54        0.00
# 168513            0.45         175882      0.45        0.00
# 168514            0.43         182733      0.21        0.00
# 168516            0.71         197092      0.62        0.00
# 168517            0.43         193280      0.15         NaN
# 168518            0.35         203600      0.39         NaN
# 168519            0.48         247360      0.40        0.00
# 168521            0.42         192587      0.41         NaN
# 168522            0.64         177787      0.14        0.00
# 168524            0.37         181693      0.29        0.00
# 168525            0.37         175493      0.26        0.00
# 168526            0.39         175827      0.41        0.00
# 168528            0.56         166893      0.19         NaN
# 168529            0.77         171000      0.25        0.00
# 168530            0.47          30000      0.28         NaN
# 168531            0.63         179493      0.25         NaN
# 168532            0.80         176120      0.17        0.00
# 168533            0.53         196043      0.20         NaN
# 168534            0.51         150777      0.27         NaN
# 168536            0.43         196693      0.31        0.00
# 168537            0.36         193653      0.36         NaN
# 168538            0.68         197507      0.31         NaN
# 168541            0.67         189493      0.46        0.00
# 168542            0.49         200760      0.26        0.00
# ...
# 168521          0.00  1930-02-22 00:00:00           0.04   100.72       0.62
# 168522          0.00  1930-03-08 00:00:00           0.10   103.77       0.54
# 168524          0.00  1930-10-03 00:00:00           0.05   110.88       0.33
# 168525          0.00  1930-06-18 00:00:00           0.05    74.28       0.84
# 168526          0.00  1930-11-03 00:00:00           0.05    88.79       0.80
# 168528          2.00  1930-07-26 00:00:00           0.03    86.41       0.39
# 168529          0.00  1930-02-19 00:00:00           0.06   113.66       0.88
# 168530          0.00  1930-05-08 00:00:00           0.05    93.68       0.97
# 168531          0.00  1930-04-26 00:00:00           0.06    99.76       0.71
# 168532          1.00  1930-11-25 00:00:00           0.08   104.06       0.62
# 168533          0.00  1930-07-11 00:00:00           0.07   100.39       0.58
# 168534          0.00  1930-01-12 00:00:00           0.10   174.47       0.42
# 168536          0.00  1930-01-06 00:00:00           0.06   124.67       0.31
# 168537          0.00  1930-03-17 00:00:00           0.05   101.89       0.55
# 168538          0.00  1930-10-13 00:00:00           0.11   177.43       0.88
# 168541          0.00  1930-10-14 00:00:00           0.32   154.61       0.98
# 168542          0.00  1930-09-05 00:00:00           0.05    79.95       0.69
# 168543          1.00  1930-11-14 00:00:00           0.14   140.98       0.91
# 168545          2.00  1930-06-03 00:00:00           0.05   110.89       0.74
# 168546          0.00  1930-03-05 00:00:00           0.04    89.13       0.56
# 168547          0.00  1930-06-16 00:00:00           0.05   111.25       0.93
# 168548          0.00  1930-03-07 00:00:00           0.04   122.28       0.76
# 168550          2.00  1930-08-18 00:00:00           0.15   134.81       0.85
# 168551          0.00  1930-01-24 00:00:00           0.06   134.68       0.72
# 168552          0.00  1930-10-14 00:00:00           0.08   171.43       0.93
# 168553          0.00  1930-10-08 00:00:00           0.08   139.07       0.77
# 168554          0.00  1930-09-26 00:00:00           0.10   125.77       0.69
# 168555          0.00  1930-11-25 00:00:00           0.08    73.42       0.41
# 168556          0.00  1930-11-21 00:00:00           0.04   126.39       0.65
# 168557          0.00  1930-09-17 00:00:00           0.05    81.29       0.40
# 168558          0.00  1930-07-25 00:00:00           0.04   107.78       0.93
# 168559          0.00  1930-08-24 00:00:00           0.03   109.34       0.62
# 168560          0.00  1930-07-14 00:00:00           0.10    70.81       0.50
# 168561          0.00  1930-02-07 00:00:00           0.11   140.16       0.88
# 168562          0.00  1930-07-06 00:00:00           0.09   101.90       0.73
# 168563          0.00  1930-02-19 00:00:00           0.06    67.14       0.60
# 168564          0.00  1930-01-27 00:00:00           0.05    97.43       0.55
# 168565          0.00  1930-10-04 00:00:00           0.07    78.46       0.32
# 168566          0.00  1930-04-18 00:00:00           0.04   113.80       0.56
# 168567          0.00  1930-06-10 00:00:00           0.33   129.00       0.62
# 168568          0.00  1930-05-13 00:00:00           0.04   112.61       0.46
# 168569          0.00  1930-08-17 00:00:00           0.06   111.08       0.63
# 168570          0.00  1930-04-24 00:00:00           0.05   119.63       0.96
# 168571          0.00  1930-07-01 00:00:00           0.05   137.83       0.54
# 168572          0.00  1930-02-23 00:00:00           0.04    80.64       0.80
# 168573          0.00  1930-11-25 00:00:00           0.07   114.56       0.71
# 168575          0.00  1930-09-19 00:00:00           0.08    77.08       0.23
# 168576          0.00  1930-11-22 00:00:00           0.06    74.37       0.26
# 168577          0.00  1935-09-22 00:00:00           0.96   165.75       0.37
# 168578          0.00  1935-08-10 00:00:00           0.05   137.71       0.84
# 168579          0.00  1935-11-26 00:00:00           0.94   126.05       0.46
# 168580          0.00  1935-01-02 00:00:00           0.95   128.77       0.45
# 168581          0.00  1935-06-13 00:00:00           0.95   174.22       0.53
# 168582          0.00  1935-04-16 00:00:00           0.04   108.83       0.95
# 168583          0.00  1935-07-15 00:00:00           0.04    87.76       0.40
# 168584          0.00  1935-11-24 00:00:00           0.45    81.29       0.46
# 168585          0.00  1935-07-15 00:00:00           0.05   137.84       0.45
# 168586          0.00  1935-09-11 00:00:00           0.06    81.88       0.82
# 168587          0.00  1935-04-05 00:00:00           0.96   147.38       0.47
# 168588          0.00  1935-05-25 00:00:00           0.05   149.40       0.69
# 168590          0.00  1935-01-05 00:00:00           0.13    64.38       0.62
# 168591          0.00  1935-04-21 00:00:00           0.03    80.95       0.12
# 168592          0.00  1935-08-09 00:00:00           0.89   130.66       0.55
# 168593          0.00  1935-10-26 00:00:00           0.06    84.88       0.04
# 168594          0.00  1935-07-04 00:00:00           0.03    56.98       0.09
# 168595          0.00  1935-04-07 00:00:00           0.04   139.60       0.39
# 168596          0.00  1935-10-06 00:00:00           0.06   109.39       0.62
#
#        t_zip Code v_genero
# 1668        12935      NaN
# 1669         7058      NaN
# 1670        38879      NaN
# 1681        12935      NaN
# 1683         7058      NaN
# 1686        38879      NaN
# 167836      98638     20.0
# 167837      81655     48.0
# 167838      47232     16.0
# 167839      75605     20.0
# 167840      68843     47.0
# 167841      16370     16.0
# 167842      62320     50.0
# 167844      81057     50.0
# 167845      22480     21.0
# 167846      17866     12.0
# 167847      38257     21.0
# 167849      41522     20.0
# 167850      87750     50.0
# 167851      43749     50.0
# 167853      23180     20.0
# 167854      24881     16.0
# 167855      65456     12.0
# 167857      99009     47.0
# 167858      13452     50.0
# 167859      10026     20.0
# 167860      12781     16.0
# 167861      48631     20.0
# 167862      99204     21.0
# 167863      12094     48.0
# 167864      49707     21.0
# 167865      98821     12.0
# 167866      37332     47.0
# 167867      40204     21.0
# 167868      80427     21.0
# 167869      36613     20.0
# 167870      99756     20.0
# 167873      92283     12.0
# 167874      60020     47.0
# 167875      95666     47.0
# 167876      17239     20.0
# 167878      28441     20.0
# 167879      52766     47.0
# 167880      95645     21.0
# 167881      50594     50.0
# 167882      61880     50.0
# 167883      16222     21.0
# 167885      61236     47.0
# 167886      17861     47.0
# 167889      29321     21.0
# 167890      75013     21.0
# 167892      40217     50.0
# 167894      28174     12.0
# 167895      80128     50.0
# 167896      32754     16.0
# 167898      62047     12.0
# 167899      43016     20.0
# 167900      45162     50.0
# 167901      45431     21.0
# 167902      87832     47.0
# 167903      78705     47.0
# 167904      21057     47.0
# 167906      71107     12.0
# 167907      72063     20.0
# 167908      55066     50.0
# 167909       2909     12.0
# 167910      41819     47.0
# 167911       7040     16.0
# 167913      95684     21.0
# 167914      91401     50.0
# 167915      45361     20.0
# 167916      74734     30.0
# 167917      93244     20.0
# 167918      34233     47.0
# 167920      44625     21.0
# 167922      94525     47.0
# 167923      19438     21.0
# 167924      91355     21.0
# 167925      22601     20.0
# 167926      33458     12.0
# 167927      98562     16.0
# 167928      39755     16.0
# 167929      36568     21.0
# 167931      57755     47.0
# 167932      41004     50.0
# 167934      15003     50.0
# 167935      27927     16.0
# 167936      76544     47.0
# 167937      24873     20.0
# 167938      50532     50.0
# 167939      27823     50.0
# 167940      74942     47.0
# 167942      71345     50.0
# 167943      87753     20.0
# 167944      51019     12.0
# 167945      84729     21.0
# 167946      54490     49.0
# 167948      24898     16.0
# 167949      51444     20.0
# 167950      46732     47.0
# 167951      74546     21.0
# 167952      24954     50.0
# 167953      87402     20.0
# 167955      14613     47.0
# 167956      24869     50.0
# 167957      94506     21.0
# 167958      98640     12.0
# 167959      16057     12.0
# 167960      97414     16.0
# 167961      17578     20.0
# 167962      19015     47.0
# 167963      85546     20.0
# 167964      63673     12.0
# 167966       3280     12.0
# 167967      32805     50.0
# 167968      49931     47.0
# 167969      40152     21.0
# 167970      65215     47.0
# 167971      77417     20.0
# 167972      93220     47.0
# 167973      73857     47.0
# 167974      57255     16.0
# 167975      10019     16.0
# 167977       1338     16.0
# 167978       2458     16.0
# 167980      71658     48.0
# 167981      33704     12.0
# 167982      48910     21.0
# 167984      97488     21.0
# 167985      66944     30.0
# 167986      25168     20.0
# 167987      99037     48.0
# 167988      91744     47.0
# 167989      27243     47.0
# 167990      92571     47.0
# 167992      30434     20.0
# 167994      37032     30.0
# 167995      83687     20.0
# 167998      24317     21.0
# 167999      20180     21.0
# 168001       1247     21.0
# 168002      48158     48.0
# 168003      97875     50.0
# 168004      32628     12.0
# 168005      14013     20.0
# 168006      54846     20.0
# 168007      54974     47.0
# 168008      23513     21.0
# 168009      58740     47.0
# 168010      42501     50.0
# 168011      95118     50.0
# 168012      43028     12.0
# 168013      63041     21.0
# 168016      95955     20.0
# 168017      95225     21.0
# 168018      63119     21.0
# 168019      46711     20.0
# 168020      13110     16.0
# 168021      24230     21.0
# 168022       8009     21.0
# 168023      99201     47.0
# 168024      49677     49.0
# 168025      97324     50.0
# 168026      69101     47.0
# 168027      77434     20.0
# 168028      64429     21.0
# 168029      66502     16.0
# 168031      19106     12.0
# 168032      25148     47.0
# 168033      97396     47.0
# 168034      28372     21.0
# 168035      38039     47.0
# 168037      15055     30.0
# 168038      59313     47.0
# 168039      75643     50.0
# 168040      49806     49.0
# 168041      15133     16.0
# 168042      67554     21.0
# 168043      13357     50.0
# 168044      40383     21.0
# 168046      27865     21.0
# 168047      47950     20.0
# 168048      61001     47.0
# 168049      48601     50.0
# 168050      81423     47.0
# 168051      95255     50.0
# 168052      58201     47.0
# 168388      98638     20.0
# 168389      47232     16.0
# 168390      68843     47.0
# 168391      62320     50.0
# 168392      81057     50.0
# 168393      22480     21.0
# 168394      17866     12.0
# 168395      38257     21.0
# 168397      87750     50.0
# 168398      43749     50.0
# 168400      23180     20.0
# 168401      24881     16.0
# 168402      65456     12.0
# 168405      10026     20.0
# 168406      12781     16.0
# 168407      48631     20.0
# 168408      99204     21.0
# 168409      12094     48.0
# 168410      49707     21.0
# 168411      98821     12.0
# 168412      37332     47.0
# 168413      40204     21.0
# 168415      36613     20.0
# 168416      99756     20.0
# 168418      22642     20.0
# 168419      92283     12.0
# 168420      60020     47.0
# 168421      95666     47.0
# 168424      28441     20.0
# 168425      52766     47.0
# 168426      95645     21.0
# 168427      50594     50.0
# 168428      61880     50.0
# 168429      16222     21.0
# 168431      61236     47.0
# 168432      17861     47.0
# 168435      29321     21.0
# 168436      75013     21.0
# 168437      67664     12.0
# 168438      40217     50.0
# 168440      28174     12.0
# 168441      80128     50.0
# 168442      32754     16.0
# 168444      62047     12.0
# 168446      45162     50.0
# 168447      45431     21.0
# 168448      87832     47.0
# 168449      78705     47.0
# 168450      21057     47.0
# 168452      71107     12.0
# 168453      72063     20.0
# 168454       2909     12.0
# 168455      41819     47.0
# 168456      68132     50.0
# 168457      95684     21.0
# 168458      91401     50.0
# 168459      45361     20.0
# 168460      74734     30.0
# 168461      93244     20.0
# 168462      34233     47.0
# 168464      44625     21.0
# 168466      94525     47.0
# 168467      19438     21.0
# 168468      91355     21.0
# 168469      22601     20.0
# 168470      33458     12.0
# 168471      98562     16.0
# 168472      39755     16.0
# 168473      36568     21.0
# 168474      77444     12.0
# 168475      57755     47.0
# 168476      41004     50.0
# 168477      11724     20.0
# 168478      15003     50.0
# 168479      27927     16.0
# 168480      76544     47.0
# 168482      50532     50.0
# 168483      27823     50.0
# 168484      74942     47.0
# 168486      71345     50.0
# 168487      87753     20.0
# 168488      51019     12.0
# 168489      84729     21.0
# 168490      54490     49.0
# 168492      24898     16.0
# 168494      46732     47.0
# 168495      74546     21.0
# 168496      24954     50.0
# 168497      87402     20.0
# 168498      44437      3.0
# 168499      14613     47.0
# 168500      24869     50.0
# 168501      94506     21.0
# 168502      98640     12.0
# 168503      16057     12.0
# 168504      97414     16.0
# 168505      17578     20.0
# 168506      19015     47.0
# 168507      85546     20.0
# 168508      63673     12.0
# 168509      35966     20.0
# 168510       3280     12.0
# 168511      32805     50.0
# 168512      49931     47.0
# 168513      40152     21.0
# 168514      65215     47.0
# 168516      93220     47.0
# 168517      73857     47.0
# 168518      57255     16.0
# 168519      10019     16.0
# 168521       1338     16.0
# 168522       2458     16.0
# 168524      71658     48.0
# 168525      33704     12.0
# 168526      48910     21.0
# 168528      97488     21.0
# 168529      66944     30.0
# 168530      25168     20.0
# 168531      99037     48.0
# 168532      91744     47.0
# 168533      27243     47.0
# 168534      92571     47.0
# 168536      30434     20.0
# 168537       2127     20.0
# 168538      37032     30.0
# 168541      83401     20.0
# 168542      24317     21.0
# 168543      20180     21.0
# 168545       1247     21.0
# 168546      48158     48.0
# 168547      97875     50.0
# 168548      32628     12.0
# 168550      54846     20.0
# 168551      54974     47.0
# 168552      23513     21.0
# 168553      58740     47.0
# 168554      42501     50.0
# 168555      95118     50.0
# 168556      43028     12.0
# 168557      63041     21.0
# 168558       4090     20.0
# 168559      26169     20.0
# 168560      95955     20.0
# 168561      95225     21.0
# 168562      63119     21.0
# 168563      46711     20.0
# 168564      13110     16.0
# 168565      24230     21.0
# 168566       8009     21.0
# 168567      99201     47.0
# 168568      49677     49.0
# 168569      97324     50.0
# 168570      69101     47.0
# 168571      77434     20.0
# 168572      64429     21.0
# 168573      66502     16.0
# 168575      19106     12.0
# 168576      25148     47.0
# 168577      97396     47.0
# 168578      28372     21.0
# 168579      38039     47.0
# 168580      49256     12.0
# 168581      15055     30.0
# 168582      59313     47.0
# 168583      75643     50.0
# 168584      49806     49.0
# 168585      15133     16.0
# 168586      67554     21.0
# 168587      13357     50.0
# 168588      40383     21.0
# 168590      27865     21.0
# 168591      47950     20.0
# 168592      61001     47.0
# 168593      48601     50.0
# 168594      81423     47.0
# 168595      95255     50.0
# 168596      58201     47.0

# %%
spotify.drop_duplicates(inplace = True)

# %%
# Verify if duplicate records were deleted
spotify.duplicated().sum()
# Out:
# 0

# %%
# Create a new index and delete the previous one
spotify.reset_index(drop = True, inplace = True)

# %%
# Verify dataframe shape after remove duplicates
print(spotify.shape)
spotify.head(5)
# Out:
# (169985, 20)
#    c_acousticness             t_artists  c_danceability  c_duration_ms  \
# 0            0.76  ['Shel Silverstein']            0.67         210387
# 1            0.92      ['Mose Allison']            0.69         149547
# 2            0.93               ['水柳仙']            0.18         207173
# 3            0.98       ['Dean Martin']            0.47         182653
# 4            0.89         ['Doris Day']            0.24         171400
#
#    c_energy  v_explicit                    t_id  c_instrumentalness  v_key  \
# 0      0.17         NaN  1r3N7MoEGPHJyCjBlWCsx3                0.00   2.00
# 1      0.24         NaN  2RL8EkOOu0QhAikhUUvIRi                0.00    NaN
# 2      0.09        0.00  3kKKEghp2EMh8992pWFylr                0.70   7.00
# 3      0.03         NaN  0j3ideT0tRuIyRhOOUQjYa                0.00   7.00
# 4      0.34         NaN  0od9zbD6Bcc8b7dCMRFWBZ                0.00   2.00
#
#    c_liveness  c_loudness  v_mode               t_name  v_popularity  \
# 0        0.13      -13.07       1          The Unicorn         12.00
# 1        0.08      -14.61       0          If You Live         19.00
# 2        0.11      -26.60       1                  鴛鴦夢         23.00
# 3        0.15      -18.01       1        Fools Rush In         21.00
# 4        0.13       -9.81       0  The Christmas Waltz         22.00
#
#         d_release_date  c_speechiness  c_tempo  c_valence t_zip Code v_genero
# 0  1962-10-13 00:00:00           0.33    97.08       0.33    38ee029      NaN
# 1  1963-04-14 00:00:00           0.04   120.89       0.71     9p2304      NaN
# 2  1963-11-14 00:00:00           0.04   101.48       0.13    2166ee6      NaN
# 3  1964-06-07 00:00:00           0.04   135.56       0.19      67t06      NaN
# 4  1964-08-07 00:00:00           0.03    89.16       0.24     804p53      NaN

# %% [markdown]
# ## **(c)** **Data Completeness**

# %%
# Function used to get completeness values
# The input/argument is --> spotify
def completeness(dataframe):
    comp = pd.DataFrame(dataframe.isnull().sum())
    comp.reset_index(inplace = True)
    comp = comp.rename(columns = {'index':'column', 0:'total'})
    comp['completeness'] = (1 - comp['total']/dataframe.shape[0])*100
    comp = comp.sort_values(by = 'completeness', ascending = True)
    comp.reset_index(drop = True, inplace = True)
    return comp

# %%
# Apply "completeness function" to spotify dataframe
completeness(spotify)
# Out:
#                 column  total  completeness
# 0           v_explicit  62905         62.99
# 1                v_key  35759         78.96
# 2         v_popularity   3501         97.94
# 3             v_genero   1698         99.00
# 4            c_valence      0        100.00
# 5              c_tempo      0        100.00
# 6        c_speechiness      0        100.00
# 7       d_release_date      0        100.00
# 8               t_name      0        100.00
# 9               v_mode      0        100.00
# 10      c_acousticness      0        100.00
# 11          t_zip Code      0        100.00
# 12  c_instrumentalness      0        100.00
# 13                t_id      0        100.00
# 14            c_energy      0        100.00
# 15       c_duration_ms      0        100.00
# 16      c_danceability      0        100.00
# 17           t_artists      0        100.00
# 18          c_loudness      0        100.00
# 19          c_liveness      0        100.00

# %% [markdown]
# ## **(d)** **Delete Variables With >=20% of Missing Value**

# %%
# Drop columns with 20% or more missing values
spotify.drop(columns = ['v_explicit', 'v_key'], inplace = True)
spotify.reset_index(drop = True, inplace = True)
print(spotify.shape)
spotify.head(5)
# Out:
# (169985, 18)
#    c_acousticness             t_artists  c_danceability  c_duration_ms  \
# 0            0.76  ['Shel Silverstein']            0.67         210387
# 1            0.92      ['Mose Allison']            0.69         149547
# 2            0.93               ['水柳仙']            0.18         207173
# 3            0.98       ['Dean Martin']            0.47         182653
# 4            0.89         ['Doris Day']            0.24         171400
#
#    c_energy                    t_id  c_instrumentalness  c_liveness  \
# 0      0.17  1r3N7MoEGPHJyCjBlWCsx3                0.00        0.13
# 1      0.24  2RL8EkOOu0QhAikhUUvIRi                0.00        0.08
# 2      0.09  3kKKEghp2EMh8992pWFylr                0.70        0.11
# 3      0.03  0j3ideT0tRuIyRhOOUQjYa                0.00        0.15
# 4      0.34  0od9zbD6Bcc8b7dCMRFWBZ                0.00        0.13
#
#    c_loudness  v_mode               t_name  v_popularity       d_release_date  \
# 0      -13.07       1          The Unicorn         12.00  1962-10-13 00:00:00
# 1      -14.61       0          If You Live         19.00  1963-04-14 00:00:00
# 2      -26.60       1                  鴛鴦夢         23.00  1963-11-14 00:00:00
# 3      -18.01       1        Fools Rush In         21.00  1964-06-07 00:00:00
# 4       -9.81       0  The Christmas Waltz         22.00  1964-08-07 00:00:00
#
#    c_speechiness  c_tempo  c_valence t_zip Code v_genero
# 0           0.33    97.08       0.33    38ee029      NaN
# 1           0.04   120.89       0.71     9p2304      NaN
# 2           0.04   101.48       0.13    2166ee6      NaN
# 3           0.04   135.56       0.19      67t06      NaN
# 4           0.03    89.16       0.24     804p53      NaN

# %% [markdown]
# ## **(e)** **How many records in the variable "zip Code" are invalid values? That is, they contain letters**

# %%
# Using regex to identify invalid records in 't_zip Code' variable (it means that contains letters)
invalid_zipcode = spotify['t_zip Code'].str.contains(r'[a-zA-Z]').sum()
print(f'Total Invalid Zip Code Records: {invalid_zipcode}')
print(f'Total Records: {spotify.shape[0]}')
# Out:
# Total Invalid Zip Code Records: 4341
# Total Records: 169985

# %% [markdown]
# ## **(f)** **Delete records that don't have a valid "zip Code", that is, it contains letters in the values**

# %%
spotify['t_zip Code'] = spotify['t_zip Code'].astype('unicode')
spotify = spotify[spotify['t_zip Code'].map(lambda x: x.isnumeric())]
spotify.reset_index(drop = True, inplace = True)
print(spotify.shape)
spotify.head(3)
# Out:
# (165644, 18)
#    c_acousticness                t_artists  c_danceability  c_duration_ms  \
# 0            0.00               ['Slayer']            0.30         400093
# 1            0.33  ['Miguel Mateos - Zas']            0.55         290640
# 2            0.00          ['Paula Abdul']            0.73         231921
#
#    c_energy                    t_id  c_instrumentalness  c_liveness  \
# 0      0.92  0dt3XQL7LjTNyizTXY00yD                0.18        0.25
# 1      0.97  096vJncZZrwi4lLUoggD9y                0.17        0.08
# 2      0.78  7xHYQboEmdZXWuXpJf9h30                0.00        0.05
#
#    c_loudness  v_mode                 t_name  v_popularity  \
# 0       -8.36       1     Crypts of Eternity         33.00
# 1       -7.04       0  Mi Sombra En la Pared         45.00
# 2       -9.13       0            Knocked Out         32.00
#
#         d_release_date  c_speechiness  c_tempo  c_valence t_zip Code v_genero
# 0  1985-05-26 00:00:00           0.07   101.92       0.14      13126      NaN
# 1  1986-10-02 00:00:00           0.08   174.59       0.79      14223      NaN
# 2  1988-08-15 00:00:00           0.05   116.23       0.95      84620      NaN

# %% [markdown]
# ## **(g)** **How many records in the variable "gender" are invalid values? , that is, they contain letters**

# %%
# Using regex to identify letters in 'v_genero'
invalid_gender = spotify['v_genero'].str.contains(r'[a-zA-Z-ZéüöêåøЧастьХемиуэйЧасть]').sum()
print(f'Total Records With Invalid Gender: {invalid_gender}')
print(f'Total Records: {spotify.shape[0]}')
# Out:
# Total Records With Invalid Gender: 10
# Total Records: 165644

# %% [markdown]
# ## **(h)** **Delete the records that don't have a valid "gender", that is, that contain letters in the values**

# %%
spotify.head(3)
# Out:
#    c_acousticness                t_artists  c_danceability  c_duration_ms  \
# 0            0.00               ['Slayer']            0.30         400093
# 1            0.33  ['Miguel Mateos - Zas']            0.55         290640
# 2            0.00          ['Paula Abdul']            0.73         231921
#
#    c_energy                    t_id  c_instrumentalness  c_liveness  \
# 0      0.92  0dt3XQL7LjTNyizTXY00yD                0.18        0.25
# 1      0.97  096vJncZZrwi4lLUoggD9y                0.17        0.08
# 2      0.78  7xHYQboEmdZXWuXpJf9h30                0.00        0.05
#
#    c_loudness  v_mode                 t_name  v_popularity  \
# 0       -8.36       1     Crypts of Eternity         33.00
# 1       -7.04       0  Mi Sombra En la Pared         45.00
# 2       -9.13       0            Knocked Out         32.00
#
#         d_release_date  c_speechiness  c_tempo  c_valence t_zip Code v_genero
# 0  1985-05-26 00:00:00           0.07   101.92       0.14      13126      NaN
# 1  1986-10-02 00:00:00           0.08   174.59       0.79      14223      NaN
# 2  1988-08-15 00:00:00           0.05   116.23       0.95      84620      NaN

# %%
spotify = spotify[~spotify['v_genero'].str.contains(r'[a-zA-Z-ZéüöêåøЧастьХемиуэйЧасть]', na=False)]
print(spotify.shape)
spotify.head(3)
# Out:
# (165634, 18)
#    c_acousticness                t_artists  c_danceability  c_duration_ms  \
# 0            0.00               ['Slayer']            0.30         400093
# 1            0.33  ['Miguel Mateos - Zas']            0.55         290640
# 2            0.00          ['Paula Abdul']            0.73         231921
#
#    c_energy                    t_id  c_instrumentalness  c_liveness  \
# 0      0.92  0dt3XQL7LjTNyizTXY00yD                0.18        0.25
# 1      0.97  096vJncZZrwi4lLUoggD9y                0.17        0.08
# 2      0.78  7xHYQboEmdZXWuXpJf9h30                0.00        0.05
#
#    c_loudness  v_mode                 t_name  v_popularity  \
# 0       -8.36       1     Crypts of Eternity         33.00
# 1       -7.04       0  Mi Sombra En la Pared         45.00
# 2       -9.13       0            Knocked Out         32.00
#
#         d_release_date  c_speechiness  c_tempo  c_valence t_zip Code v_genero
# 0  1985-05-26 00:00:00           0.07   101.92       0.14      13126      NaN
# 1  1986-10-02 00:00:00           0.08   174.59       0.79      14223      NaN
# 2  1988-08-15 00:00:00           0.05   116.23       0.95      84620      NaN

# %% [markdown]
# ## **(i)** **Clean the variable "name", remove special characters and everything must be in lowercase**

# %%
# This functions just map the column 'name' to keep names even if they have asian characters
import re
def cjk_detect(texts):
    # Korean
    if re.search("[\uac00-\ud7a3]", texts):
        return texts
    # Japanese
    if re.search("[\u3040-\u30ff]", texts):
        return texts
    # Chinese
    if re.search("[\u4e00-\u9FFF]", texts):
        return texts
    else:
        return texts

# %%
# This functions is used to remove special marks/characters
def remove_punct(text):
    try:
        text=text.replace(".",' ').replace(";",' ').replace(":",' ').replace(",",' ')
        text=text.replace("(",' ').replace(")",' ').replace("|",' ').replace('"',' ')
        text=text.replace("%",' ').replace("$",' ').replace("/",' ').replace('\'',' ')
        text=text.replace("-",' ').replace("_",' ').replace("*",' ').replace('+',' ')
        text=text.replace("#",' ').replace("@",' ').replace("!",' ').replace('?',' ')
        text=text.replace("[",' ').replace("]",' ').replace("'",' ').replace('¡',' ')
    except:
        pass
    return text

# %%
# This functions is used to clean 'name' and convert to lowercase
def clean_text(text):
    text=text.lower()
    text=remove_punct(text)
    return text

# %%
# Apply 'cjk_detect' function just to return text in its native format
spotify['t_name'] = spotify['t_name'].apply(lambda row: cjk_detect(row))
spotify.reset_index(drop = True, inplace = True)
spotify.head(5)
# Out:
#    c_acousticness                t_artists  c_danceability  c_duration_ms  \
# 0            0.00               ['Slayer']            0.30         400093
# 1            0.33  ['Miguel Mateos - Zas']            0.55         290640
# 2            0.00          ['Paula Abdul']            0.73         231921
# 3            0.74           ['Henry Fiol']            0.71         305058
# 4            0.74         ['Eric Clapton']            0.60         216800
#
#    c_energy                    t_id  c_instrumentalness  c_liveness  \
# 0      0.92  0dt3XQL7LjTNyizTXY00yD                0.18        0.25
# 1      0.97  096vJncZZrwi4lLUoggD9y                0.17        0.08
# 2      0.78  7xHYQboEmdZXWuXpJf9h30                0.00        0.05
# 3      0.63  6M5z2Pca6OuN4l5n5kId3E                0.00        0.09
# 4      0.22  5tdEWfBGNX7a7zD78tUwLZ                0.06        0.88
#
#    c_loudness  v_mode                                             t_name  \
# 0       -8.36       1                                 Crypts of Eternity
# 1       -7.04       0                              Mi Sombra En la Pared
# 2       -9.13       0                                        Knocked Out
# 3      -10.36       0                                            Zumbale
# 4      -15.05       0  Walkin' Blues - Acoustic; Live at MTV Unplugge...
#
#    v_popularity       d_release_date  c_speechiness  c_tempo  c_valence  \
# 0         33.00  1985-05-26 00:00:00           0.07   101.92       0.14
# 1         45.00  1986-10-02 00:00:00           0.08   174.59       0.79
# 2         32.00  1988-08-15 00:00:00           0.05   116.23       0.95
# 3         46.00  1991-04-16 00:00:00           0.04    95.45       0.92
# 4         45.00  1992-08-15 00:00:00           0.05    85.33       0.41
#
#   t_zip Code v_genero
# 0      13126      NaN
# 1      14223      NaN
# 2      84620      NaN
# 3      22824      NaN
# 4      27519      NaN

# %%
# Apply 'clean_text' function to convert it to lowercase without affect (Japanese, Chinese & Korean) names
spotify['t_name'] = spotify['t_name'].apply(lambda row: clean_text(row))
spotify.reset_index(drop = True, inplace = True)
spotify.head(5)
# Out:
#    c_acousticness                t_artists  c_danceability  c_duration_ms  \
# 0            0.00               ['Slayer']            0.30         400093
# 1            0.33  ['Miguel Mateos - Zas']            0.55         290640
# 2            0.00          ['Paula Abdul']            0.73         231921
# 3            0.74           ['Henry Fiol']            0.71         305058
# 4            0.74         ['Eric Clapton']            0.60         216800
#
#    c_energy                    t_id  c_instrumentalness  c_liveness  \
# 0      0.92  0dt3XQL7LjTNyizTXY00yD                0.18        0.25
# 1      0.97  096vJncZZrwi4lLUoggD9y                0.17        0.08
# 2      0.78  7xHYQboEmdZXWuXpJf9h30                0.00        0.05
# 3      0.63  6M5z2Pca6OuN4l5n5kId3E                0.00        0.09
# 4      0.22  5tdEWfBGNX7a7zD78tUwLZ                0.06        0.88
#
#    c_loudness  v_mode                                             t_name  \
# 0       -8.36       1                                 crypts of eternity
# 1       -7.04       0                              mi sombra en la pared
# 2       -9.13       0                                        knocked out
# 3      -10.36       0                                            zumbale
# 4      -15.05       0  walkin  blues   acoustic  live at mtv unplugge...
#
#    v_popularity       d_release_date  c_speechiness  c_tempo  c_valence  \
# 0         33.00  1985-05-26 00:00:00           0.07   101.92       0.14
# 1         45.00  1986-10-02 00:00:00           0.08   174.59       0.79
# 2         32.00  1988-08-15 00:00:00           0.05   116.23       0.95
# 3         46.00  1991-04-16 00:00:00           0.04    95.45       0.92
# 4         45.00  1992-08-15 00:00:00           0.05    85.33       0.41
#
#   t_zip Code v_genero
# 0      13126      NaN
# 1      14223      NaN
# 2      84620      NaN
# 3      22824      NaN
# 4      27519      NaN

# %% [markdown]
# ## **(j)** **From the variable "artist" select only the first one that appears in the list in addition eliminate special characters**

# %%
first_artist = spotify['t_artists'].iloc[0]
clean_first_artist = clean_text(first_artist)
clean_first_artist = remove_punct(first_artist)
print(f'No Clean First Artist: {first_artist}')
print(f'Clean First Artist: {clean_first_artist}')
# Out:
# No Clean First Artist: ['Slayer']
# Clean First Artist:   Slayer

# %% [markdown]
# ## **(k)** **Normalize the variable "gender" in such a way that you get only 8 categories**

# %%
print(spotify.shape)
# Out:
# (165634, 18)

# %%
# Checking for null values in 'v_genero' variable
spotify['v_genero'].isnull().sum()
# Out:
# 1642

# %%
spotify['v_genero'].value_counts()
# Out:
# 47.0    27168
# 20.0    24872
# 50.0    20154
# 12.0    18329
# 16.0    18067
# 21.0    17834
# 47.0     5812
# 20.0     5398
# 50.0     4247
# 21.0     3899
# 16.0     3843
# 12.0     3774
# 30.0     2653
# 49.0     2627
# 48.0     2566
# 30.0      579
# 49.0      566
# 48.0      551
# 3.0       448
# 2.0       286
# 1.0       147
# 3.0        84
# 2.0        65
# 1.0        23
# Name: v_genero, dtype: int64

# %%
spotify['v_genero'].value_counts(normalize=True)
# Out:
# 47.0   0.17
# 20.0   0.15
# 50.0   0.12
# 12.0   0.11
# 16.0   0.11
# 21.0   0.11
# 47.0   0.04
# 20.0   0.03
# 50.0   0.03
# 21.0   0.02
# 16.0   0.02
# 12.0   0.02
# 30.0   0.02
# 49.0   0.02
# 48.0   0.02
# 30.0   0.00
# 49.0   0.00
# 48.0   0.00
# 3.0    0.00
# 2.0    0.00
# 1.0    0.00
# 3.0    0.00
# 2.0    0.00
# 1.0    0.00
# Name: v_genero, dtype: float64

# %%
spotify['v_genero'].value_counts(1)[-4].sum()
# Out:
# 0.0008963851895214401

# %%
spotify['v_genero'].value_counts(1)[-3:].sum()
# Out:
# 0.001048831650324406

# %%
spotify_genero_norm = dict(zip(list(spotify['v_genero'].value_counts(1)[-17:].index),['Others']*90))
spotify_genero_norm
# Out:
# {'20.0': 'Others',
#  '50.0': 'Others',
#  '21.0': 'Others',
#  '16.0': 'Others',
#  '12.0': 'Others',
#  30.0: 'Others',
#  49.0: 'Others',
#  48.0: 'Others',
#  '30.0': 'Others',
#  '49.0': 'Others',
#  '48.0': 'Others',
#  3.0: 'Others',
#  2.0: 'Others',
#  1.0: 'Others',
#  '3.0': 'Others',
#  '2.0': 'Others',
#  '1.0': 'Others'}

# %%
spotify['v_genero'].replace(spotify_genero_norm).value_counts()
# Out:
# Others    31756
# 47.0      27168
# 20.0      24872
# 50.0      20154
# 12.0      18329
# 16.0      18067
# 21.0      17834
# 47.0       5812
# Name: v_genero, dtype: int64

# %% [markdown]
# ## **(l)** **Add the following columns to your dataset: zip, lat, lng, city, state name using the zips table**

# %%
# Read 'zips_practica.csv' data table
zips = pd.read_csv('zips_practica.csv')
print(zips.shape)
zips.head(4)
# Out:
# (33099, 19)
#    zip   lat    lng          city state_id      state_name  zcta  parent_zcta  \
# 0  601 18.18 -66.75    Adjunta28s       PR  Puerto 345Rico  True          NaN
# 1  602 18.36 -67.18     A543guada       PR  P733uerto Rico  True          NaN
# 2  603 18.45 -67.12  Ag188uadilla       PR  Pue888rto Rico  True          NaN
# 3  606 18.17 -66.94    Ma297ricao       PR  Puerto Ric683o  True          NaN
#
#    population  density  county_fips county_name  \
# 0       17242   111.40        72001    Adjuntas
# 1       38442   523.50        72003      Aguada
# 2       48814   667.90        72005   Aguadilla
# 3        6437    60.40        72093     Maricao
#
#                               county_weights             county_names_all  \
# 0               {'72001':99.43,'72141':0.57}              Adjuntas|Utuado
# 1                              {'72003':100}                       Aguada
# 2                              {'72005':100}                    Aguadilla
# 3  {'72093':94.88,'72121':1.35,'72153':3.78}  Maricao|Yauco|Sabana Grande
#
#      county_fips_all  imprecise  military             timezone  c_lng
# 0        72001|72141      False     False  America/Puerto_Rico    NaN
# 1              72003      False     False  America/Puerto_Rico    NaN
# 2              72005      False     False  America/Puerto_Rico    NaN
# 3  72093|72153|72121      False     False  America/Puerto_Rico    NaN

# %%
zips.dtypes
# Out:
# zip                   int64
# lat                 float64
# lng                 float64
# city                 object
# state_id             object
# state_name           object
# zcta                   bool
# parent_zcta         float64
# population            int64
# density             float64
# county_fips           int64
# county_name          object
# county_weights       object
# county_names_all     object
# county_fips_all      object
# imprecise              bool
# military               bool
# timezone             object
# c_lng               float64
# dtype: object

# %%
spotify.dtypes
# Out:
# c_acousticness        float64
# t_artists              object
# c_danceability        float64
# c_duration_ms           int64
# c_energy              float64
# t_id                   object
# c_instrumentalness    float64
# c_liveness            float64
# c_loudness            float64
# v_mode                  int64
# t_name                 object
# v_popularity          float64
# d_release_date         object
# c_speechiness         float64
# c_tempo               float64
# c_valence             float64
# t_zip Code             object
# v_genero               object
# dtype: object

# %%
zips_subset = zips[['zip','lat','lng','city','state_name']]
print(zips_subset.shape)
zips_subset.head(3)
# Out:
# (33099, 5)
#    zip   lat    lng          city      state_name
# 0  601 18.18 -66.75    Adjunta28s  Puerto 345Rico
# 1  602 18.36 -67.18     A543guada  P733uerto Rico
# 2  603 18.45 -67.12  Ag188uadilla  Pue888rto Rico

# %%
spotify.head(3)
# Out:
#    c_acousticness                t_artists  c_danceability  c_duration_ms  \
# 0            0.00               ['Slayer']            0.30         400093
# 1            0.33  ['Miguel Mateos - Zas']            0.55         290640
# 2            0.00          ['Paula Abdul']            0.73         231921
#
#    c_energy                    t_id  c_instrumentalness  c_liveness  \
# 0      0.92  0dt3XQL7LjTNyizTXY00yD                0.18        0.25
# 1      0.97  096vJncZZrwi4lLUoggD9y                0.17        0.08
# 2      0.78  7xHYQboEmdZXWuXpJf9h30                0.00        0.05
#
#    c_loudness  v_mode                 t_name  v_popularity  \
# 0       -8.36       1     crypts of eternity         33.00
# 1       -7.04       0  mi sombra en la pared         45.00
# 2       -9.13       0            knocked out         32.00
#
#         d_release_date  c_speechiness  c_tempo  c_valence t_zip Code v_genero
# 0  1985-05-26 00:00:00           0.07   101.92       0.14      13126      NaN
# 1  1986-10-02 00:00:00           0.08   174.59       0.79      14223      NaN
# 2  1988-08-15 00:00:00           0.05   116.23       0.95      84620      NaN

# %%
spotify['t_zip Code'] = spotify['t_zip Code'].astype(str).astype(int)

# %%
# Merge spotify & zips_subset dataframes
from pandas.core.reshape.merge import merge
spotify = spotify.merge(zips_subset,right_on = 'zip',left_on = 't_zip Code', how = 'left')
print(spotify.shape)
spotify.head(5)
# Out:
# (165634, 23)
#    c_acousticness                t_artists  c_danceability  c_duration_ms  \
# 0            0.00               ['Slayer']            0.30         400093
# 1            0.33  ['Miguel Mateos - Zas']            0.55         290640
# 2            0.00          ['Paula Abdul']            0.73         231921
# 3            0.74           ['Henry Fiol']            0.71         305058
# 4            0.74         ['Eric Clapton']            0.60         216800
#
#    c_energy                    t_id  c_instrumentalness  c_liveness  \
# 0      0.92  0dt3XQL7LjTNyizTXY00yD                0.18        0.25
# 1      0.97  096vJncZZrwi4lLUoggD9y                0.17        0.08
# 2      0.78  7xHYQboEmdZXWuXpJf9h30                0.00        0.05
# 3      0.63  6M5z2Pca6OuN4l5n5kId3E                0.00        0.09
# 4      0.22  5tdEWfBGNX7a7zD78tUwLZ                0.06        0.88
#
#    c_loudness  v_mode                                             t_name  \
# 0       -8.36       1                                 crypts of eternity
# 1       -7.04       0                              mi sombra en la pared
# 2       -9.13       0                                        knocked out
# 3      -10.36       0                                            zumbale
# 4      -15.05       0  walkin  blues   acoustic  live at mtv unplugge...
#
#    v_popularity       d_release_date  c_speechiness  c_tempo  c_valence  \
# 0         33.00  1985-05-26 00:00:00           0.07   101.92       0.14
# 1         45.00  1986-10-02 00:00:00           0.08   174.59       0.79
# 2         32.00  1988-08-15 00:00:00           0.05   116.23       0.95
# 3         46.00  1991-04-16 00:00:00           0.04    95.45       0.92
# 4         45.00  1992-08-15 00:00:00           0.05    85.33       0.41
#
#    t_zip Code v_genero    zip   lat     lng         city        state_name
# 0       13126      NaN  13126 43.43  -76.46    Osweg970o        N18ew York
# 1       14223      NaN  14223 42.97  -78.85   Bu542ffalo       New747 York
# 2       84620      NaN  84620 38.91 -111.93    Au287rora           277Utah
# 3       22824      NaN  22824 38.84  -78.63  Edinbur844g       630Virginia
# 4       27519      NaN  27519 35.81  -78.89      C492ary  N29orth Carolina

# %% [markdown]
# ## **(m)** **Convert the variables "lat" and "lng" into a float type and validate data consistency**

# %%
# Convert 'lat' & 'lng' to float type variables
spotify['lat'] = spotify['lat'].astype(str).astype(float)
spotify['lng'] = spotify['lng'].astype(str).astype(float)

# %%
# Verify that 'lat' and 'lng are float type variables' --> consistency
spotify.dtypes
# Out:
# c_acousticness        float64
# t_artists              object
# c_danceability        float64
# c_duration_ms           int64
# c_energy              float64
# t_id                   object
# c_instrumentalness    float64
# c_liveness            float64
# c_loudness            float64
# v_mode                  int64
# t_name                 object
# v_popularity          float64
# d_release_date         object
# c_speechiness         float64
# c_tempo               float64
# c_valence             float64
# t_zip Code              int64
# v_genero               object
# zip                     int64
# lat                   float64
# lng                   float64
# city                   object
# state_name             object
# dtype: object

# %%
spotify['lat'].value_counts()
# Out:
# 39.98    20
# 45.28    19
# 31.43    19
# 39.85    19
# 41.67    19
#          ..
# 39.16     1
# 37.31     1
# 34.89     1
# 34.89     1
# 41.57     1
# Name: lat, Length: 32554, dtype: int64

# %%
# Validate 'lat' & 'lng' values
    ## Latitude must be a number between -90 and 90
    ## Longitude must a number between -180 and 180

def lat_val(value):
    if -90<=value<=+90:
        return 'Correct'
    else:
        return 'Incorrect'
    
def lng_val(value):
    if -180<=value<=+180:
        return 'Correct'
    else:
        return 'Incorrect'

# %%
# This temporal variable is created to validate 'lat' values are correct
spotify['lat_validation'] = spotify['lat'].apply(lambda row: lat_val(row))
spotify.head(5)
# Out:
#    c_acousticness                t_artists  c_danceability  c_duration_ms  \
# 0            0.00               ['Slayer']            0.30         400093
# 1            0.33  ['Miguel Mateos - Zas']            0.55         290640
# 2            0.00          ['Paula Abdul']            0.73         231921
# 3            0.74           ['Henry Fiol']            0.71         305058
# 4            0.74         ['Eric Clapton']            0.60         216800
#
#    c_energy                    t_id  c_instrumentalness  c_liveness  \
# 0      0.92  0dt3XQL7LjTNyizTXY00yD                0.18        0.25
# 1      0.97  096vJncZZrwi4lLUoggD9y                0.17        0.08
# 2      0.78  7xHYQboEmdZXWuXpJf9h30                0.00        0.05
# 3      0.63  6M5z2Pca6OuN4l5n5kId3E                0.00        0.09
# 4      0.22  5tdEWfBGNX7a7zD78tUwLZ                0.06        0.88
#
#    c_loudness  v_mode                                             t_name  \
# 0       -8.36       1                                 crypts of eternity
# 1       -7.04       0                              mi sombra en la pared
# 2       -9.13       0                                        knocked out
# 3      -10.36       0                                            zumbale
# 4      -15.05       0  walkin  blues   acoustic  live at mtv unplugge...
#
#    v_popularity       d_release_date  c_speechiness  c_tempo  c_valence  \
# 0         33.00  1985-05-26 00:00:00           0.07   101.92       0.14
# 1         45.00  1986-10-02 00:00:00           0.08   174.59       0.79
# 2         32.00  1988-08-15 00:00:00           0.05   116.23       0.95
# 3         46.00  1991-04-16 00:00:00           0.04    95.45       0.92
# 4         45.00  1992-08-15 00:00:00           0.05    85.33       0.41
#
#    t_zip Code v_genero    zip   lat     lng         city        state_name  \
# 0       13126      NaN  13126 43.43  -76.46    Osweg970o        N18ew York
# 1       14223      NaN  14223 42.97  -78.85   Bu542ffalo       New747 York
# 2       84620      NaN  84620 38.91 -111.93    Au287rora           277Utah
# 3       22824      NaN  22824 38.84  -78.63  Edinbur844g       630Virginia
# 4       27519      NaN  27519 35.81  -78.89      C492ary  N29orth Carolina
#
#   lat_validation
# 0        Correct
# 1        Correct
# 2        Correct
# 3        Correct
# 4        Correct

# %%
# This temporal variable is created to validate 'lng' values are correct
spotify['lng_validation'] = spotify['lng'].apply(lambda row: lat_val(row))
spotify.head(10)
# Out:
#    c_acousticness                 t_artists  c_danceability  c_duration_ms  \
# 0            0.00                ['Slayer']            0.30         400093
# 1            0.33   ['Miguel Mateos - Zas']            0.55         290640
# 2            0.00           ['Paula Abdul']            0.73         231921
# 3            0.74            ['Henry Fiol']            0.71         305058
# 4            0.74          ['Eric Clapton']            0.60         216800
# 5            0.04        ['Tracy Lawrence']            0.61         173667
# 6            0.00                   ['311']            0.62         257827
# 7            0.03  ['Bone Thugs-N-Harmony']            0.88         292147
# 8            0.13                ['H.O.T.']            0.74         217227
# 9            0.50        ['Lee Ann Womack']            0.52         212920
#
#    c_energy                    t_id  c_instrumentalness  c_liveness  \
# 0      0.92  0dt3XQL7LjTNyizTXY00yD                0.18        0.25
# 1      0.97  096vJncZZrwi4lLUoggD9y                0.17        0.08
# 2      0.78  7xHYQboEmdZXWuXpJf9h30                0.00        0.05
# 3      0.63  6M5z2Pca6OuN4l5n5kId3E                0.00        0.09
# 4      0.22  5tdEWfBGNX7a7zD78tUwLZ                0.06        0.88
# 5      0.62  5eSPQr9YN3vxkpuOM30wks                0.00        0.27
# 6      0.97  1JRxOhK2heeRsBsB2Dt4Vs                0.00        0.11
# 7      0.47  27LvxLKUfzL6b6WMdOQAVU                0.00        0.17
# 8      0.98  0K25zmumCzn2kFmh9zcLWy                0.00        0.14
# 9      0.28  1rVZ7EqoVJfrciRW80Uljh                0.00        0.13
#
#    c_loudness  v_mode                                             t_name  \
# 0       -8.36       1                                 crypts of eternity
# 1       -7.04       0                              mi sombra en la pared
# 2       -9.13       0                                        knocked out
# 3      -10.36       0                                            zumbale
# 4      -15.05       0  walkin  blues   acoustic  live at mtv unplugge...
# 5      -13.76       1                         can t break it to my heart
# 6       -6.31       1                                       do you right
# 7      -10.65       1                               no shorts  no losses
# 8       -2.32       1                                              candy
# 9      -10.60       1                                           the fool
#
#    v_popularity       d_release_date  c_speechiness  c_tempo  c_valence  \
# 0         33.00  1985-05-26 00:00:00           0.07   101.92       0.14
# 1         45.00  1986-10-02 00:00:00           0.08   174.59       0.79
# 2         32.00  1988-08-15 00:00:00           0.05   116.23       0.95
# 3         46.00  1991-04-16 00:00:00           0.04    95.45       0.92
# 4         45.00  1992-08-15 00:00:00           0.05    85.33       0.41
# 5         34.00  1993-01-11 00:00:00           0.03   136.45       0.74
# 6         34.00  1993-11-08 00:00:00           0.10   110.03       0.48
# 7         38.00  1995-04-23 00:00:00           0.24   141.38       0.87
# 8         47.00  1996-02-27 00:00:00           0.04   119.99       0.95
# 9         39.00  1997-06-25 00:00:00           0.03    80.10       0.29
#
#    t_zip Code v_genero    zip   lat     lng              city  \
# 0       13126      NaN  13126 43.43  -76.46         Osweg970o
# 1       14223      NaN  14223 42.97  -78.85        Bu542ffalo
# 2       84620      NaN  84620 38.91 -111.93         Au287rora
# 3       22824      NaN  22824 38.84  -78.63       Edinbur844g
# 4       27519      NaN  27519 35.81  -78.89           C492ary
# 5       66527      NaN  66527 39.75  -95.68      P696owhattan
# 6       24060      NaN  24060 37.26  -80.42     Blacksb286urg
# 7       58062      NaN  58062 46.64  -97.83           Nom402e
# 8       72347      NaN  72347 35.39  -91.00  Hickory 539Ridge
# 9       44827      NaN  44827 40.82  -82.76      Crestli544ne
#
#          state_name lat_validation lng_validation
# 0        N18ew York        Correct        Correct
# 1       New747 York        Correct        Correct
# 2           277Utah        Correct      Incorrect
# 3       630Virginia        Correct        Correct
# 4  N29orth Carolina        Correct        Correct
# 5         Kans810as        Correct      Incorrect
# 6       Vir629ginia        Correct        Correct
# 7   North Dako638ta        Correct      Incorrect
# 8       Ar160kansas        Correct      Incorrect
# 9           686Ohio        Correct        Correct

# %%
# Checking 'lat' & 'lng' variables are 'Correct' for all records
spotify['lng_validation'].value_counts()
# Out:
# Correct      90980
# Incorrect    74654
# Name: lng_validation, dtype: int64

# %%
# Checking 'lat' & 'lng' variables are 'Correct' for all records
spotify['lat_validation'].value_counts()
# Out:
# Correct    165634
# Name: lat_validation, dtype: int64

# %% [markdown]
# ## **(n)** **From the variable "city" and "state" remove the digits found within the text strings**

# %%
spotify['city'] = spotify['city'].str.replace(r'[0-9]','')
spotify['state_name'] = spotify['state_name'].str.replace(r'[0-9]','')
print(spotify.shape)
spotify.head(5)
# Out:
# (165634, 25)
#    c_acousticness                t_artists  c_danceability  c_duration_ms  \
# 0            0.00               ['Slayer']            0.30         400093
# 1            0.33  ['Miguel Mateos - Zas']            0.55         290640
# 2            0.00          ['Paula Abdul']            0.73         231921
# 3            0.74           ['Henry Fiol']            0.71         305058
# 4            0.74         ['Eric Clapton']            0.60         216800
#
#    c_energy                    t_id  c_instrumentalness  c_liveness  \
# 0      0.92  0dt3XQL7LjTNyizTXY00yD                0.18        0.25
# 1      0.97  096vJncZZrwi4lLUoggD9y                0.17        0.08
# 2      0.78  7xHYQboEmdZXWuXpJf9h30                0.00        0.05
# 3      0.63  6M5z2Pca6OuN4l5n5kId3E                0.00        0.09
# 4      0.22  5tdEWfBGNX7a7zD78tUwLZ                0.06        0.88
#
#    c_loudness  v_mode                                             t_name  \
# 0       -8.36       1                                 crypts of eternity
# 1       -7.04       0                              mi sombra en la pared
# 2       -9.13       0                                        knocked out
# 3      -10.36       0                                            zumbale
# 4      -15.05       0  walkin  blues   acoustic  live at mtv unplugge...
#
#    v_popularity       d_release_date  c_speechiness  c_tempo  c_valence  \
# 0         33.00  1985-05-26 00:00:00           0.07   101.92       0.14
# 1         45.00  1986-10-02 00:00:00           0.08   174.59       0.79
# 2         32.00  1988-08-15 00:00:00           0.05   116.23       0.95
# 3         46.00  1991-04-16 00:00:00           0.04    95.45       0.92
# 4         45.00  1992-08-15 00:00:00           0.05    85.33       0.41
#
#    t_zip Code v_genero    zip   lat     lng      city      state_name  \
# 0       13126      NaN  13126 43.43  -76.46    Oswego        New York
# 1       14223      NaN  14223 42.97  -78.85   Buffalo        New York
# 2       84620      NaN  84620 38.91 -111.93    Aurora            Utah
# 3       22824      NaN  22824 38.84  -78.63  Edinburg        Virginia
# 4       27519      NaN  27519 35.81  -78.89      Cary  North Carolina
#
#   lat_validation lng_validation
# 0        Correct        Correct
# 1        Correct        Correct
# 2        Correct      Incorrect
# 3        Correct        Correct
# 4        Correct        Correct

# %% [markdown]
# ## **(o)** **Create a new variable called "state" that is made up of "city" & "state name"**

# %%
spotify['state'] = spotify[['city', 'state_name']].agg(', '.join, axis=1)
print(spotify.shape)
spotify.head(3)
# Out:
# (165634, 26)
#    c_acousticness                t_artists  c_danceability  c_duration_ms  \
# 0            0.00               ['Slayer']            0.30         400093
# 1            0.33  ['Miguel Mateos - Zas']            0.55         290640
# 2            0.00          ['Paula Abdul']            0.73         231921
#
#    c_energy                    t_id  c_instrumentalness  c_liveness  \
# 0      0.92  0dt3XQL7LjTNyizTXY00yD                0.18        0.25
# 1      0.97  096vJncZZrwi4lLUoggD9y                0.17        0.08
# 2      0.78  7xHYQboEmdZXWuXpJf9h30                0.00        0.05
#
#    c_loudness  v_mode                 t_name  v_popularity  \
# 0       -8.36       1     crypts of eternity         33.00
# 1       -7.04       0  mi sombra en la pared         45.00
# 2       -9.13       0            knocked out         32.00
#
#         d_release_date  c_speechiness  c_tempo  c_valence  t_zip Code  \
# 0  1985-05-26 00:00:00           0.07   101.92       0.14       13126
# 1  1986-10-02 00:00:00           0.08   174.59       0.79       14223
# 2  1988-08-15 00:00:00           0.05   116.23       0.95       84620
#
#   v_genero    zip   lat     lng     city state_name lat_validation  \
# 0      NaN  13126 43.43  -76.46   Oswego   New York        Correct
# 1      NaN  14223 42.97  -78.85  Buffalo   New York        Correct
# 2      NaN  84620 38.91 -111.93   Aurora       Utah        Correct
#
#   lng_validation              state
# 0        Correct   Oswego, New York
# 1        Correct  Buffalo, New York
# 2      Incorrect       Aurora, Utah

# %% [markdown]
# ## **(p)** **The values of the new variable "state", modify them in a certain way that all o them must be in lowercase and without accents**

# %%
# Convert 'state' column to lowercase
spotify['state'] = spotify['state'].apply(lambda x:x.lower())
spotify.head(5)
# Out:
#    c_acousticness                t_artists  c_danceability  c_duration_ms  \
# 0            0.00               ['Slayer']            0.30         400093
# 1            0.33  ['Miguel Mateos - Zas']            0.55         290640
# 2            0.00          ['Paula Abdul']            0.73         231921
# 3            0.74           ['Henry Fiol']            0.71         305058
# 4            0.74         ['Eric Clapton']            0.60         216800
#
#    c_energy                    t_id  c_instrumentalness  c_liveness  \
# 0      0.92  0dt3XQL7LjTNyizTXY00yD                0.18        0.25
# 1      0.97  096vJncZZrwi4lLUoggD9y                0.17        0.08
# 2      0.78  7xHYQboEmdZXWuXpJf9h30                0.00        0.05
# 3      0.63  6M5z2Pca6OuN4l5n5kId3E                0.00        0.09
# 4      0.22  5tdEWfBGNX7a7zD78tUwLZ                0.06        0.88
#
#    c_loudness  v_mode                                             t_name  \
# 0       -8.36       1                                 crypts of eternity
# 1       -7.04       0                              mi sombra en la pared
# 2       -9.13       0                                        knocked out
# 3      -10.36       0                                            zumbale
# 4      -15.05       0  walkin  blues   acoustic  live at mtv unplugge...
#
#    v_popularity       d_release_date  c_speechiness  c_tempo  c_valence  \
# 0         33.00  1985-05-26 00:00:00           0.07   101.92       0.14
# 1         45.00  1986-10-02 00:00:00           0.08   174.59       0.79
# 2         32.00  1988-08-15 00:00:00           0.05   116.23       0.95
# 3         46.00  1991-04-16 00:00:00           0.04    95.45       0.92
# 4         45.00  1992-08-15 00:00:00           0.05    85.33       0.41
#
#    t_zip Code v_genero    zip   lat     lng      city      state_name  \
# 0       13126      NaN  13126 43.43  -76.46    Oswego        New York
# 1       14223      NaN  14223 42.97  -78.85   Buffalo        New York
# 2       84620      NaN  84620 38.91 -111.93    Aurora            Utah
# 3       22824      NaN  22824 38.84  -78.63  Edinburg        Virginia
# 4       27519      NaN  27519 35.81  -78.89      Cary  North Carolina
#
#   lat_validation lng_validation                 state
# 0        Correct        Correct      oswego, new york
# 1        Correct        Correct     buffalo, new york
# 2        Correct      Incorrect          aurora, utah
# 3        Correct        Correct    edinburg, virginia
# 4        Correct        Correct  cary, north carolina

# %%
# This function is used to delete 'accents' with the 'unicodedata' library
def delete_accents(s):
    return ''.join(c for c in unicodedata.normalize('NFD', s)
                  if unicodedata.category(c) != 'Mn')

# %%
spotify['state'] = spotify['state'].apply(lambda row: delete_accents(row))
spotify.head(5)
# Out:
#    c_acousticness                t_artists  c_danceability  c_duration_ms  \
# 0            0.00               ['Slayer']            0.30         400093
# 1            0.33  ['Miguel Mateos - Zas']            0.55         290640
# 2            0.00          ['Paula Abdul']            0.73         231921
# 3            0.74           ['Henry Fiol']            0.71         305058
# 4            0.74         ['Eric Clapton']            0.60         216800
#
#    c_energy                    t_id  c_instrumentalness  c_liveness  \
# 0      0.92  0dt3XQL7LjTNyizTXY00yD                0.18        0.25
# 1      0.97  096vJncZZrwi4lLUoggD9y                0.17        0.08
# 2      0.78  7xHYQboEmdZXWuXpJf9h30                0.00        0.05
# 3      0.63  6M5z2Pca6OuN4l5n5kId3E                0.00        0.09
# 4      0.22  5tdEWfBGNX7a7zD78tUwLZ                0.06        0.88
#
#    c_loudness  v_mode                                             t_name  \
# 0       -8.36       1                                 crypts of eternity
# 1       -7.04       0                              mi sombra en la pared
# 2       -9.13       0                                        knocked out
# 3      -10.36       0                                            zumbale
# 4      -15.05       0  walkin  blues   acoustic  live at mtv unplugge...
#
#    v_popularity       d_release_date  c_speechiness  c_tempo  c_valence  \
# 0         33.00  1985-05-26 00:00:00           0.07   101.92       0.14
# 1         45.00  1986-10-02 00:00:00           0.08   174.59       0.79
# 2         32.00  1988-08-15 00:00:00           0.05   116.23       0.95
# 3         46.00  1991-04-16 00:00:00           0.04    95.45       0.92
# 4         45.00  1992-08-15 00:00:00           0.05    85.33       0.41
#
#    t_zip Code v_genero    zip   lat     lng      city      state_name  \
# 0       13126      NaN  13126 43.43  -76.46    Oswego        New York
# 1       14223      NaN  14223 42.97  -78.85   Buffalo        New York
# 2       84620      NaN  84620 38.91 -111.93    Aurora            Utah
# 3       22824      NaN  22824 38.84  -78.63  Edinburg        Virginia
# 4       27519      NaN  27519 35.81  -78.89      Cary  North Carolina
#
#   lat_validation lng_validation                 state
# 0        Correct        Correct      oswego, new york
# 1        Correct        Correct     buffalo, new york
# 2        Correct      Incorrect          aurora, utah
# 3        Correct        Correct    edinburg, virginia
# 4        Correct        Correct  cary, north carolina

# %%
spotify['d_release_date'].unique()
# Out:
# array(['1985-05-26 00:00:00', '1986-10-02 00:00:00',
#        '1988-08-15 00:00:00', ..., '1928-11-08 00:00:00',
#        '1928-10-24 00:00:00', '1930-01-04 00:00:00'], dtype=object)

# %% [markdown]
# ## **(q)** **Convert the values in the variable "release date" to type datetime, also count those that do not have the necessary structure to be converted into datetime and delete those records**

# %%
# (q)-I Verify invalid records in 'release_date' (don't have the correct datetime format)
invalid_date = spotify['d_release_date'].str.contains(r'[a-zA-Z]').sum()
print(f'Total Records With Incorrect Structure: {invalid_date}')
print(f'Total Records: {spotify.shape[0]}')
# Out:
# Total Records With Incorrect Structure: 0
# Total Records: 165634

# %% [markdown]
# ### (q)-II Due to 0 incorrect structure records in 'release_date' --> delete not required

# %%
# (q)-III Convert 'release_date' records to datetime type
spotify['d_release_date'] = pd.to_datetime(spotify['d_release_date'], format = '%Y-%m-%d %H:%M:%S')
spotify.head(3)
# Out:
#    c_acousticness                t_artists  c_danceability  c_duration_ms  \
# 0            0.00               ['Slayer']            0.30         400093
# 1            0.33  ['Miguel Mateos - Zas']            0.55         290640
# 2            0.00          ['Paula Abdul']            0.73         231921
#
#    c_energy                    t_id  c_instrumentalness  c_liveness  \
# 0      0.92  0dt3XQL7LjTNyizTXY00yD                0.18        0.25
# 1      0.97  096vJncZZrwi4lLUoggD9y                0.17        0.08
# 2      0.78  7xHYQboEmdZXWuXpJf9h30                0.00        0.05
#
#    c_loudness  v_mode                 t_name  v_popularity d_release_date  \
# 0       -8.36       1     crypts of eternity         33.00     1985-05-26
# 1       -7.04       0  mi sombra en la pared         45.00     1986-10-02
# 2       -9.13       0            knocked out         32.00     1988-08-15
#
#    c_speechiness  c_tempo  c_valence  t_zip Code v_genero    zip   lat  \
# 0           0.07   101.92       0.14       13126      NaN  13126 43.43
# 1           0.08   174.59       0.79       14223      NaN  14223 42.97
# 2           0.05   116.23       0.95       84620      NaN  84620 38.91
#
#       lng     city state_name lat_validation lng_validation              state
# 0  -76.46   Oswego   New York        Correct        Correct   oswego, new york
# 1  -78.85  Buffalo   New York        Correct        Correct  buffalo, new york
# 2 -111.93   Aurora       Utah        Correct      Incorrect       aurora, utah

# %%
spotify.dtypes
# Out:
# c_acousticness               float64
# t_artists                     object
# c_danceability               float64
# c_duration_ms                  int64
# c_energy                     float64
# t_id                          object
# c_instrumentalness           float64
# c_liveness                   float64
# c_loudness                   float64
# v_mode                         int64
# t_name                        object
# v_popularity                 float64
# d_release_date        datetime64[ns]
# c_speechiness                float64
# c_tempo                      float64
# c_valence                    float64
# t_zip Code                     int64
# v_genero                      object
# zip                            int64
# lat                          float64
# lng                          float64
# city                          object
# state_name                    object
# lat_validation                object
# lng_validation                object
# state                         object
# dtype: object

# %% [markdown]
# # 2. **From the treated dataset obtain the following data:**

# %% [markdown]
# ## **(a)** **Get a DataFrame showing the record count by gender**

# %%
gender_count = spotify['v_genero'].value_counts()
gender_count = pd.DataFrame(gender_count)
gender_count = gender_count.rename(columns = {0:'v_genero','v_genero':'total'})
gender_count
# Out:
#       total
# 47.0  27168
# 20.0  24872
# 50.0  20154
# 12.0  18329
# 16.0  18067
# 21.0  17834
# 47.0   5812
# 20.0   5398
# 50.0   4247
# 21.0   3899
# 16.0   3843
# 12.0   3774
# 30.0   2653
# 49.0   2627
# 48.0   2566
# 30.0    579
# 49.0    566
# 48.0    551
# 3.0     448
# 2.0     286
# 1.0     147
# 3.0      84
# 2.0      65
# 1.0      23

# %% [markdown]
# ## **(b)** **Create a new variable called "duration_minutos" that is the value of the variable "duration_ms" in minutes**

# %%
spotify.head(3)
# Out:
#    c_acousticness                t_artists  c_danceability  c_duration_ms  \
# 0            0.00               ['Slayer']            0.30         400093
# 1            0.33  ['Miguel Mateos - Zas']            0.55         290640
# 2            0.00          ['Paula Abdul']            0.73         231921
#
#    c_energy                    t_id  c_instrumentalness  c_liveness  \
# 0      0.92  0dt3XQL7LjTNyizTXY00yD                0.18        0.25
# 1      0.97  096vJncZZrwi4lLUoggD9y                0.17        0.08
# 2      0.78  7xHYQboEmdZXWuXpJf9h30                0.00        0.05
#
#    c_loudness  v_mode                 t_name  v_popularity d_release_date  \
# 0       -8.36       1     crypts of eternity         33.00     1985-05-26
# 1       -7.04       0  mi sombra en la pared         45.00     1986-10-02
# 2       -9.13       0            knocked out         32.00     1988-08-15
#
#    c_speechiness  c_tempo  c_valence  t_zip Code v_genero    zip   lat  \
# 0           0.07   101.92       0.14       13126      NaN  13126 43.43
# 1           0.08   174.59       0.79       14223      NaN  14223 42.97
# 2           0.05   116.23       0.95       84620      NaN  84620 38.91
#
#       lng     city state_name lat_validation lng_validation              state
# 0  -76.46   Oswego   New York        Correct        Correct   oswego, new york
# 1  -78.85  Buffalo   New York        Correct        Correct  buffalo, new york
# 2 -111.93   Aurora       Utah        Correct      Incorrect       aurora, utah

# %%
spotify['duration_minutos'] = (spotify['c_duration_ms']/60)
print(spotify.shape)
spotify.head(3)
# Out:
# (165634, 27)
#    c_acousticness                t_artists  c_danceability  c_duration_ms  \
# 0            0.00               ['Slayer']            0.30         400093
# 1            0.33  ['Miguel Mateos - Zas']            0.55         290640
# 2            0.00          ['Paula Abdul']            0.73         231921
#
#    c_energy                    t_id  c_instrumentalness  c_liveness  \
# 0      0.92  0dt3XQL7LjTNyizTXY00yD                0.18        0.25
# 1      0.97  096vJncZZrwi4lLUoggD9y                0.17        0.08
# 2      0.78  7xHYQboEmdZXWuXpJf9h30                0.00        0.05
#
#    c_loudness  v_mode                 t_name  v_popularity d_release_date  \
# 0       -8.36       1     crypts of eternity         33.00     1985-05-26
# 1       -7.04       0  mi sombra en la pared         45.00     1986-10-02
# 2       -9.13       0            knocked out         32.00     1988-08-15
#
#    c_speechiness  c_tempo  c_valence  t_zip Code v_genero    zip   lat  \
# 0           0.07   101.92       0.14       13126      NaN  13126 43.43
# 1           0.08   174.59       0.79       14223      NaN  14223 42.97
# 2           0.05   116.23       0.95       84620      NaN  84620 38.91
#
#       lng     city state_name lat_validation lng_validation  \
# 0  -76.46   Oswego   New York        Correct        Correct
# 1  -78.85  Buffalo   New York        Correct        Correct
# 2 -111.93   Aurora       Utah        Correct      Incorrect
#
#                state  duration_minutos
# 0   oswego, new york          6,668.22
# 1  buffalo, new york          4,844.00
# 2       aurora, utah          3,865.35

# %% [markdown]
# ## **(c)** **What are the 10 most popular songs?**

# %%
# Create a 'popularity' variable to identify most popular songs
popularity = spotify.sort_values(by = 'v_popularity', ascending = False)
popularity.reset_index(drop = True, inplace = True)
popularity.head(3)
# Out:
#    c_acousticness                  t_artists  c_danceability  c_duration_ms  \
# 0            0.00             ['The Weeknd']            0.51         200040
# 1            0.25  ['DaBaby', 'Roddy Ricch']            0.75         181733
# 2            0.73   ['Powfu', 'beabadoobee']            0.73         173333
#
#    c_energy                    t_id  c_instrumentalness  c_liveness  \
# 0      0.73  0VjIjW4GlUZAMYd2vXMi3b                0.00        0.09
# 1      0.69  7ytR5pFWmSjzHJIeQkgog4                0.00        0.10
# 2      0.43  7eJMfftS33KTjuF7lTsMCx                0.00        0.70
#
#    c_loudness  v_mode                                             t_name  \
# 0       -5.93       1                                    blinding lights
# 1       -7.96       1                       rockstar  feat  roddy ricch
# 2       -8.77       0  death bed  coffee for your head   feat  beabad...
#
#    v_popularity d_release_date  c_speechiness  c_tempo  c_valence  t_zip Code  \
# 0        100.00     2020-03-11           0.06   171.00       0.33       78663
# 1         99.00     2020-06-20           0.16    89.98       0.50       46404
# 2         97.00     2020-04-27           0.14   144.03       0.35       38725
#
#   v_genero    zip   lat    lng            city   state_name lat_validation  \
# 0     12.0  78663 30.42 -98.34  Round Mountain        Texas        Correct
# 1     12.0  46404 41.58 -87.37            Gary      Indiana        Correct
# 2     50.0  38725 33.65 -91.03          Benoit  Mississippi        Correct
#
#   lng_validation                  state  duration_minutos
# 0      Incorrect  round mountain, texas          3,334.00
# 1        Correct          gary, indiana          3,028.88
# 2      Incorrect    benoit, mississippi          2,888.88

# %%
# 10 most popular songs base in 'v_popularity' value are:
most_popular = popularity[['t_artists','v_popularity']]
most_popular.reset_index(drop = True, inplace = True)
most_popular.head(10)
# Out:
#                                     t_artists  v_popularity
# 0                              ['The Weeknd']        100.00
# 1                   ['DaBaby', 'Roddy Ricch']         99.00
# 2                    ['Powfu', 'beabadoobee']         97.00
# 3  ['THE SCOTTS', 'Travis Scott', 'Kid Cudi']         96.00
# 4                                   ['Drake']         95.00
# 5                             ['Roddy Ricch']         95.00
# 6                  ['BENEE', 'Gus Dapperton']         95.00
# 7                     ['Surf Mesa', 'Emilee']         95.00
# 8                             ['Tones And I']         94.00
# 9              ['Lady Gaga', 'Ariana Grande']         94.00

# %% [markdown]
# ## **(d)** **What is the average duration in minutes and milliseconds?**

# %%
# Get the average duration in 'minutes'
average_minutes = spotify['duration_minutos'].mean()
print(f'Average Duration In Minutes: {average_minutes}')
# Out:
# Average Duration In Minutes: 3856.467707113221

# %%
# Get the average duration in 'miliseconds'
average_miliseconds = spotify['c_duration_ms'].mean()
print(f'Average Duration In Miliseconds: {average_miliseconds}')
# Out:
# Average Duration In Miliseconds: 231388.06242679644

# %% [markdown]
# ## **(e)** **What is the 'average' and 'count' of "energy" by "gender"?**

# %%
spotify.head(3)
# Out:
#    c_acousticness                t_artists  c_danceability  c_duration_ms  \
# 0            0.00               ['Slayer']            0.30         400093
# 1            0.33  ['Miguel Mateos - Zas']            0.55         290640
# 2            0.00          ['Paula Abdul']            0.73         231921
#
#    c_energy                    t_id  c_instrumentalness  c_liveness  \
# 0      0.92  0dt3XQL7LjTNyizTXY00yD                0.18        0.25
# 1      0.97  096vJncZZrwi4lLUoggD9y                0.17        0.08
# 2      0.78  7xHYQboEmdZXWuXpJf9h30                0.00        0.05
#
#    c_loudness  v_mode                 t_name  v_popularity d_release_date  \
# 0       -8.36       1     crypts of eternity         33.00     1985-05-26
# 1       -7.04       0  mi sombra en la pared         45.00     1986-10-02
# 2       -9.13       0            knocked out         32.00     1988-08-15
#
#    c_speechiness  c_tempo  c_valence  t_zip Code v_genero    zip   lat  \
# 0           0.07   101.92       0.14       13126      NaN  13126 43.43
# 1           0.08   174.59       0.79       14223      NaN  14223 42.97
# 2           0.05   116.23       0.95       84620      NaN  84620 38.91
#
#       lng     city state_name lat_validation lng_validation  \
# 0  -76.46   Oswego   New York        Correct        Correct
# 1  -78.85  Buffalo   New York        Correct        Correct
# 2 -111.93   Aurora       Utah        Correct      Incorrect
#
#                state  duration_minutos
# 0   oswego, new york          6,668.22
# 1  buffalo, new york          4,844.00
# 2       aurora, utah          3,865.35

# %%
spotify.dtypes
# Out:
# c_acousticness               float64
# t_artists                     object
# c_danceability               float64
# c_duration_ms                  int64
# c_energy                     float64
# t_id                          object
# c_instrumentalness           float64
# c_liveness                   float64
# c_loudness                   float64
# v_mode                         int64
# t_name                        object
# v_popularity                 float64
# d_release_date        datetime64[ns]
# c_speechiness                float64
# c_tempo                      float64
# c_valence                    float64
# t_zip Code                     int64
# v_genero                      object
# zip                            int64
# lat                          float64
# lng                          float64
# city                          object
# state_name                    object
# lat_validation                object
# lng_validation                object
# state                         object
# duration_minutos             float64
# dtype: object

# %%
spotify['v_genero'] = spotify['v_genero'].astype(str).astype(float)

# %%
# This is the average of 'energy' by 'gender'
energyByGenderMean = spotify.groupby('v_genero')['c_energy'].mean()
pd.DataFrame(energyByGenderMean)
# Out:
#           c_energy
# v_genero
# 1.00          0.49
# 2.00          0.48
# 3.00          0.47
# 12.00         0.49
# 16.00         0.49
# 20.00         0.49
# 21.00         0.49
# 30.00         0.49
# 47.00         0.49
# 48.00         0.49
# 49.00         0.49
# 50.00         0.49

# %%
# This is the count of 'energy' by 'gender'
energyByGenderCount = spotify.groupby('v_genero')['c_energy'].count()
pd.DataFrame(energyByGenderCount)
# Out:
#           c_energy
# v_genero
# 1.00           170
# 2.00           351
# 3.00           532
# 12.00        22103
# 16.00        21910
# 20.00        30270
# 21.00        21733
# 30.00         3232
# 47.00        32980
# 48.00         3117
# 49.00         3193
# 50.00        24401

# %% [markdown]
# ## **(f)** **Which song has the lowest "loudness" and which song has the highest one**

# %%
# Get song with lowest 'loedness'
    ## As we can see, we have 9 songs with the same 'loudness' (minimum value = -60)
min_loadness_song = spotify[spotify['c_loudness'] == spotify['c_loudness'].min()]
min_loadness_song.reset_index(drop = True, inplace = True)
min_loadness_song
# Out:
#    c_acousticness             t_artists  c_danceability  c_duration_ms  \
# 0            0.00    ['Connie Francis']            0.00         179466
# 1            0.00     ['Sarah Vaughan']            0.00           6467
# 2            0.00  ['Robert Earl Keen']            0.00          60372
# 3            0.00        ['Atlas Fret']            0.00         132827
# 4            0.00    ['Connie Francis']            0.00         253719
# 5            0.00     ['Benny Goodman']            0.00           5991
# 6            0.00     ['Benny Goodman']            0.00           6362
# 7            0.00     ['Future Rapper']            0.00         420000
# 8            0.00     ['Sarah Vaughan']            0.00           5108
#
#    c_energy                    t_id  c_instrumentalness  c_liveness  \
# 0      0.00  0zr7DJGTPUfAUmjM7crmt2                0.00        0.00
# 1      0.00  3lRVIn6D6EUbvkOgPZAU1H                0.00        0.00
# 2      0.00  0o12mLSQuXFgsh4e2Kc4e5                0.00        0.00
# 3      0.00  7cctPQS83y620UQtMd1ilL                0.00        0.00
# 4      0.00  5KAJv7Bceihn1frqElloIb                0.00        0.00
# 5      0.00  3IcXTeq9O2dpsSXsDj9naH                0.00        0.00
# 6      0.00  523qs4UcGlQ6ycdha1VGqs                0.00        0.00
# 7      0.00  0Rd7eiAZGayLT8TmrVpQzG                0.00        0.00
# 8      0.00  0hr9kRUi2X4MXc72A4VxG4                0.00        0.00
#
#    c_loudness  v_mode                               t_name  v_popularity  \
# 0      -60.00       0                         hava nagilah         12.00
# 1      -60.00       0                          pause track          0.00
# 2      -60.00       0                         silent track         35.00
# 3      -60.00       0                        silent track          40.00
# 4      -60.00       0                    my yiddishe momme         12.00
# 5      -60.00       0                   pause track   live          0.00
# 6      -60.00       0                   pause track   live          0.00
# 7      -60.00       0  staggerlee has his day at the beach          0.00
# 8      -60.00       0                          pause track          0.00
#
#   d_release_date  c_speechiness  c_tempo  c_valence  t_zip Code  v_genero  \
# 0     1960-11-03           0.00     0.00       0.00       27344     47.00
# 1     1949-05-24           0.00     0.00       0.00       77619     47.00
# 2     1998-09-21           0.00     0.00       0.00       93541     20.00
# 3     2007-08-24           0.00     0.00       0.00       47585     12.00
# 4     1960-03-27           0.00     0.00       0.00        6357     47.00
# 5     1938-01-05           0.00     0.00       0.00       14548     16.00
# 6     1938-02-13           0.00     0.00       0.00        7470     20.00
# 7     1949-01-10           0.00     0.00       0.00       15208     12.00
# 8     1949-02-24           0.00     0.00       0.00       95823     20.00
#
#      zip   lat     lng         city      state_name lat_validation  \
# 0  27344 35.73  -79.43   Siler City  North Carolina        Correct
# 1  77619 29.95  -93.92       Groves           Texas        Correct
# 2  93541 37.98 -119.12   Lee Vining      California        Correct
# 3  47585 38.27  -87.15      Stendal         Indiana        Correct
# 4   6357 41.33  -72.22      Niantic     Connecticut        Correct
# 5  14548 42.98  -77.24  Shortsville        New York        Correct
# 6   7470 40.95  -74.25        Wayne      New Jersey        Correct
# 7  15208 40.45  -79.90   Pittsburgh    Pennsylvania        Correct
# 8  95823 38.47 -121.44   Sacramento      California        Correct
#
#   lng_validation                       state  duration_minutos
# 0        Correct  siler city, north carolina          2,991.10
# 1      Incorrect               groves, texas            107.78
# 2      Incorrect      lee vining, california          1,006.20
# 3        Correct            stendal, indiana          2,213.78
# 4        Correct        niantic, connecticut          4,228.65
# 5        Correct       shortsville, new york             99.85
# 6        Correct           wayne, new jersey            106.03
# 7        Correct    pittsburgh, pennsylvania          7,000.00
# 8      Incorrect      sacramento, california             85.13

# %%
# Get song with highest 'loudness'
    ## As we can see, in this case we have just 1 song with maximum 'loudness'(maximum value = 3.85)
max_loadness_song = spotify[spotify['c_loudness'] == spotify['c_loudness'].max()]
max_loadness_song.reset_index(drop = True, inplace = True)
max_loadness_song
# Out:
#    c_acousticness         t_artists  c_danceability  c_duration_ms  c_energy  \
# 0            0.00  ['Apocolothoth']            0.00         152476      0.11
#
#                      t_id  c_instrumentalness  c_liveness  c_loudness  v_mode  \
# 0  050FXMyCrQJG01AT55Jvk1                1.00        0.58        3.85       0
#
#   t_name  v_popularity d_release_date  c_speechiness  c_tempo  c_valence  \
# 0   sold          0.00     1936-10-06           0.00     0.00       0.00
#
#    t_zip Code  v_genero    zip   lat    lng         city state_name  \
# 0       37766     16.00  37766 36.40 -84.09  La Follette  Tennessee
#
#   lat_validation lng_validation                   state  duration_minutos
# 0        Correct        Correct  la follette, tennessee          2,541.27

# %%
# To validate results in the gotten number of songs:
    ## Lets see records based in 'c_loudness' for the lowest value
aux = spotify['c_loudness'].sort_values(ascending = True)
aux.reset_index(drop = True, inplace = True)
aux = pd.DataFrame(aux)
aux.head(10)
# Out:
#    c_loudness
# 0      -60.00
# 1      -60.00
# 2      -60.00
# 3      -60.00
# 4      -60.00
# 5      -60.00
# 6      -60.00
# 7      -60.00
# 8      -60.00
# 9      -55.00

# %%
# To validate results in the gotten number of songs above:
    ## Lets see records based in 'c_loudness' for the highest value
aux.tail(3)
# Out:
#         c_loudness
# 165631        2.80
# 165632        3.74
# 165633        3.85

# %% [markdown]
# ## **(g)** **Obtain the 10 percentiles of the continuous variables**

# %%
spotify.head(3)
# Out:
#    c_acousticness                t_artists  c_danceability  c_duration_ms  \
# 0            0.00               ['Slayer']            0.30         400093
# 1            0.33  ['Miguel Mateos - Zas']            0.55         290640
# 2            0.00          ['Paula Abdul']            0.73         231921
#
#    c_energy                    t_id  c_instrumentalness  c_liveness  \
# 0      0.92  0dt3XQL7LjTNyizTXY00yD                0.18        0.25
# 1      0.97  096vJncZZrwi4lLUoggD9y                0.17        0.08
# 2      0.78  7xHYQboEmdZXWuXpJf9h30                0.00        0.05
#
#    c_loudness  v_mode                 t_name  v_popularity d_release_date  \
# 0       -8.36       1     crypts of eternity         33.00     1985-05-26
# 1       -7.04       0  mi sombra en la pared         45.00     1986-10-02
# 2       -9.13       0            knocked out         32.00     1988-08-15
#
#    c_speechiness  c_tempo  c_valence  t_zip Code  v_genero    zip   lat  \
# 0           0.07   101.92       0.14       13126       NaN  13126 43.43
# 1           0.08   174.59       0.79       14223       NaN  14223 42.97
# 2           0.05   116.23       0.95       84620       NaN  84620 38.91
#
#       lng     city state_name lat_validation lng_validation  \
# 0  -76.46   Oswego   New York        Correct        Correct
# 1  -78.85  Buffalo   New York        Correct        Correct
# 2 -111.93   Aurora       Utah        Correct      Incorrect
#
#                state  duration_minutos
# 0   oswego, new york          6,668.22
# 1  buffalo, new york          4,844.00
# 2       aurora, utah          3,865.35

# %%
# Get 10 percentiles for 'c_acousticness'
spotify['c_acousticness'].describe(percentiles=[.1,.2,.3,.4,.5,.6,.7,.8,.9,1])
# Out:
# count   165,634.00
# mean          0.49
# std           0.38
# min           0.00
# 10%           0.01
# 20%           0.05
# 30%           0.14
# 40%           0.29
# 50%           0.48
# 60%           0.68
# 70%           0.83
# 80%           0.93
# 90%           0.98
# 100%          1.00
# max           1.00
# Name: c_acousticness, dtype: float64

# %%
# Get 10 percentiles for 'c_danceability'
spotify['c_danceability'].describe(percentiles=[.1,.2,.3,.4,.5,.6,.7,.8,.9,1])
# Out:
# count   165,634.00
# mean          0.54
# std           0.18
# min           0.00
# 10%           0.30
# 20%           0.39
# 30%           0.45
# 40%           0.50
# 50%           0.55
# 60%           0.60
# 70%           0.64
# 80%           0.70
# 90%           0.76
# 100%          0.99
# max           0.99
# Name: c_danceability, dtype: float64

# %%
# Get 10 percentiles for 'c_duration_ms'
spotify['c_duration_ms'].describe(percentiles=[.1,.2,.3,.4,.5,.6,.7,.8,.9,1])
# Out:
# count     165,634.00
# mean      231,388.06
# std       120,842.92
# min         5,108.00
# 10%       137,640.00
# 20%       162,560.00
# 30%       179,293.00
# 40%       193,620.20
# 50%       208,853.50
# 60%       227,533.00
# 70%       249,840.00
# 80%       279,765.20
# 90%       335,342.80
# 100%    5,403,500.00
# max     5,403,500.00
# Name: c_duration_ms, dtype: float64

# %%
# Get 10 percentiles for 'c_energy'
spotify['c_energy'].describe(percentiles=[.1,.2,.3,.4,.5,.6,.7,.8,.9,1])
# Out:
# count   165,634.00
# mean          0.49
# std           0.27
# min           0.00
# 10%           0.13
# 20%           0.22
# 30%           0.31
# 40%           0.40
# 50%           0.48
# 60%           0.57
# 70%           0.67
# 80%           0.76
# 90%           0.87
# 100%          1.00
# max           1.00
# Name: c_energy, dtype: float64

# %%
# Get 10 percentiles for 'c_instrumentalness'
spotify['c_instrumentalness'].describe(percentiles=[.1,.2,.3,.4,.5,.6,.7,.8,.9,1])
# Out:
# count   165,634.00
# mean          0.16
# std           0.31
# min           0.00
# 10%           0.00
# 20%           0.00
# 30%           0.00
# 40%           0.00
# 50%           0.00
# 60%           0.00
# 70%           0.02
# 80%           0.28
# 90%           0.83
# 100%          1.00
# max           1.00
# Name: c_instrumentalness, dtype: float64

# %%
# Get 10 percentiles for 'c_liveness'
spotify['c_liveness'].describe(percentiles=[.1,.2,.3,.4,.5,.6,.7,.8,.9,1])
# Out:
# count   165,634.00
# mean          0.21
# std           0.18
# min           0.00
# 10%           0.07
# 20%           0.09
# 30%           0.10
# 40%           0.12
# 50%           0.14
# 60%           0.17
# 70%           0.22
# 80%           0.30
# 90%           0.41
# 100%          1.00
# max           1.00
# Name: c_liveness, dtype: float64

# %%
# Get 10 percentiles for 'c_loudness'
spotify['c_loudness'].describe(percentiles=[.1,.2,.3,.4,.5,.6,.7,.8,.9,1])
# Out:
# count   165,634.00
# mean        -11.32
# std           5.67
# min         -60.00
# 10%         -18.87
# 20%         -15.57
# 30%         -13.45
# 40%         -11.86
# 50%         -10.42
# 60%          -9.07
# 70%          -7.73
# 80%          -6.41
# 90%          -4.99
# 100%          3.85
# max           3.85
# Name: c_loudness, dtype: float64

# %%
print(spotify.shape)
spotify.head(5)
# Out:
# (165634, 27)
#    c_acousticness                t_artists  c_danceability  c_duration_ms  \
# 0            0.00               ['Slayer']            0.30         400093
# 1            0.33  ['Miguel Mateos - Zas']            0.55         290640
# 2            0.00          ['Paula Abdul']            0.73         231921
# 3            0.74           ['Henry Fiol']            0.71         305058
# 4            0.74         ['Eric Clapton']            0.60         216800
#
#    c_energy                    t_id  c_instrumentalness  c_liveness  \
# 0      0.92  0dt3XQL7LjTNyizTXY00yD                0.18        0.25
# 1      0.97  096vJncZZrwi4lLUoggD9y                0.17        0.08
# 2      0.78  7xHYQboEmdZXWuXpJf9h30                0.00        0.05
# 3      0.63  6M5z2Pca6OuN4l5n5kId3E                0.00        0.09
# 4      0.22  5tdEWfBGNX7a7zD78tUwLZ                0.06        0.88
#
#    c_loudness  v_mode                                             t_name  \
# 0       -8.36       1                                 crypts of eternity
# 1       -7.04       0                              mi sombra en la pared
# 2       -9.13       0                                        knocked out
# 3      -10.36       0                                            zumbale
# 4      -15.05       0  walkin  blues   acoustic  live at mtv unplugge...
#
#    v_popularity d_release_date  c_speechiness  c_tempo  c_valence  t_zip Code  \
# 0         33.00     1985-05-26           0.07   101.92       0.14       13126
# 1         45.00     1986-10-02           0.08   174.59       0.79       14223
# 2         32.00     1988-08-15           0.05   116.23       0.95       84620
# 3         46.00     1991-04-16           0.04    95.45       0.92       22824
# 4         45.00     1992-08-15           0.05    85.33       0.41       27519
#
#    v_genero    zip   lat     lng      city      state_name lat_validation  \
# 0       NaN  13126 43.43  -76.46    Oswego        New York        Correct
# 1       NaN  14223 42.97  -78.85   Buffalo        New York        Correct
# 2       NaN  84620 38.91 -111.93    Aurora            Utah        Correct
# 3       NaN  22824 38.84  -78.63  Edinburg        Virginia        Correct
# 4       NaN  27519 35.81  -78.89      Cary  North Carolina        Correct
#
#   lng_validation                 state  duration_minutos
# 0        Correct      oswego, new york          6,668.22
# 1        Correct     buffalo, new york          4,844.00
# 2      Incorrect          aurora, utah          3,865.35
# 3        Correct    edinburg, virginia          5,084.30
# 4        Correct  cary, north carolina          3,613.33
